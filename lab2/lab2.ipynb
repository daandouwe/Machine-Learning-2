# %% [markdown]
# # Lab 2: Inference in Graphical Models
#
# ### Machine Learning 2 (2016/2017)
#
# * The lab exercises should be made in groups of two people or individually.
# * The hand-in deadline is Wednesday, May 10, 23:59.
# * Assignment should be sent to p.j.j.p.versteeg@uva.nl. The subject line of your email should be "[ML2_2017] lab#_lastname1\_lastname2".
# * Put your and your teammates' names in the body of the email
# * Attach the .IPYNB (IPython Notebook) file containing your code and answers. Naming of the file follows the same rule as the subject line. For example, if the subject line is "[ML2_2017] lab02\_Bongers\_Blom", the attached file should be "lab02\_Bongers\_Blom.ipynb". Only use underscores ("\_") to connect names, otherwise the files cannot be parsed.
#
# Notes on implementation:
#
# * You should write your code and answers in an IPython Notebook: http://ipython.org/notebook.html. If you have problems, please ask or e-mail Philip.
# * For some of the questions, you can write the code directly in the first code cell that provides the class structure.
# * Among the first lines of your notebook should be "%pylab inline". This imports all required modules, and your plots will appear inline.
# * NOTE: test your code and make sure we can run your notebook / scripts!

# %% [markdown]
# ### Introduction
# In this assignment, we will implement the sum-product and max-sum algorithms for factor graphs over discrete variables. The relevant theory is covered in chapter 8 of Bishop's PRML book, in particular section 8.4. Read this chapter carefuly before continuing!
#
# We will first implement sum-product and max-sum and apply it to a simple poly-tree structured factor graph for medical diagnosis. Then, we will implement a loopy version of the algorithms and use it for image denoising.
#
# For this assignment we recommended you stick to numpy ndarrays (constructed with np.array, np.zeros, np.ones, etc.) as opposed to numpy matrices, because arrays can store n-dimensional arrays whereas matrices only work for 2d arrays. We need n-dimensional arrays in order to store conditional distributions with more than 1 conditioning variable. If you want to perform matrix multiplication on arrays, use the np.dot function; all infix operators including *, +, -, work element-wise on arrays.

# %% [markdown]
# ## Part 1: The sum-product algorithm
#
# We will implement a datastructure to store a factor graph and to facilitate computations on this graph. Recall that a factor graph consists of two types of nodes, factors and variables. Below you will find some classes for these node types to get you started. Carefully inspect this code and make sure you understand what it does; you will have to build on it later.

# %%
# %pylab inline
class Node(object):
    """
    Base-class for Nodes in a factor graph. Only instantiate sub-classes of Node.
    """
    def __init__(self, name):
        # A name for this Node, for printing purposes
        self.name = name
        
        # Neighbours in the graph, identified with their index in this list.
        # i.e. self.neighbours contains neighbour 0 through len(self.neighbours) - 1.
        self.neighbours = []
        
        # Reset the node-state (not the graph topology)
        self.reset()
        
    def reset(self):
        # Incoming messages; a dictionary mapping neighbours to messages.
        # That is, it maps  Node -> np.ndarray.
        self.in_msgs = {}
        
        # A set of neighbours for which this node has pending messages.
        # We use a python set object so we don't have to worry about duplicates.
        self.pending = set([])

    def add_neighbour(self, nb):
        self.neighbours.append(nb)

    def send_sp_msg(self, other):
        # To be implemented in subclass.
        raise Exception('Method send_sp_msg not implemented in base-class Node')
   
    def send_ms_msg(self, other):
        # To be implemented in subclass.
        raise Exception('Method send_ms_msg not implemented in base-class Node')
    
    def receive_msg(self, other, msg):
        # Store the incomming message, replacing previous messages from the same node
        self.in_msgs[other] = msg

#         self.pending.update(set(self.neighbours) - set([other]))

#         all_other_nodes = [node for node in self.neighbours if not node == other]
#         received_from = set(self.in_msgs.keys())
#         to_append_nodes = []
#         for node in all_other_nodes:
#             other_nodes = set([n for n in self.neighbours if not n == node])
#             if other_nodes <= received_from:
#                 to_append_nodes.append(node)
#         self.pending.update(to_append_nodes)  
        
        ms = set(self.neighbours) - {other}
        ready_to_send_nodes = []
        for neighbour in ms:
            # if we havent received message from this neighbour
            if neighbour not in self.in_msgs:
                # if all other neighbours already received message, then
#                 if len(self.neighbours) - 1 == len(self.in_msgs):
                    # ready to send message to this neighbour
                    ready_to_send_nodes.append(neighbour)
            # if we have received message from this neighbour
            else:
                # check if all neighbours already received message, then
#                 if len(self.neighbours) == len(self.in_msgs):
                    # ready to send message to this neighbour
                    ready_to_send_nodes.append(neighbour)


    def __str__(self):
        # This is printed when using 'print node_instance'
        return self.name


class Variable(Node):
    def __init__(self, name, num_states):
        """
        Variable node constructor.
        Args:
            name: a name string for this node. Used for printing. 
            num_states: the number of states this variable can take.
            Allowable states run from 0 through (num_states - 1).
            For example, for a binary variable num_states=2,
            and the allowable states are 0, 1.
        """
        self.num_states = num_states
        
        # Call the base-class constructor
        super(Variable, self).__init__(name)
    
    def set_observed(self, observed_state):
        """
        Set this variable to an observed state.
        Args:
            observed_state: an integer value in [0, self.num_states - 1].
        """
        # Observed state is represented as a 1-of-N variable
        # Could be 0.0 for sum-product, but log(0.0) = -inf so a tiny value is preferable for max-sum
        self.observed_state[:] = 0.000001
        self.observed_state[observed_state] = 1.0
        
    def set_latent(self):
        """
        Erase an observed state for this variable and consider it latent again.
        """
        # No state is preferred, so set all entries of observed_state to 1.0
        # Using this representation we need not differentiate between observed and latent
        # variables when sending messages.
        self.observed_state[:] = 1.0
        
    def reset(self):
        super(Variable, self).reset()
        self.observed_state = np.ones(self.num_states)
        
    def marginal(self, Z=None):
        """
        Compute the marginal distribution of this Variable.
        It is assumed that message passing has completed when this function is called.
        Args:
            Z: an optional normalization constant can be passed in. If None is passed, Z is computed.
        Returns: marginal, Z. The first is a numpy array containing the normalized marginal distribution.
         Z is either equal to the input Z, or computed in this function (if Z=None was passed).
        """
        for nb in self.neighbours:
            assert nb in self.in_msgs.keys(), "Cannot compute marginal: missing message from variable {}".format(nb)
        mus = [self.in_msgs[nb] for nb in self.neighbours] + [self.observed_state]
        prod = np.multiply.reduce(mus)
        if Z == None:
            # compute Z
            Z = np.sum(prod)
            pass
        marginal = 1/Z * prod
        return marginal, Z
    
    def send_sp_msg(self, other):
        # Variable -> Factor message for sum-product
        assert type(other) == Factor, "Other node needs to a be Factor, received {}".format(other)
        for nb in self.neighbours:
            if not nb == other:
                assert nb in self.in_msgs.keys(), "Missing message from variable {}".format(nb)
        # all messages present
        if len(self.neighbours) == 1:
            # leaf variable-node
            message = self.observed_state
            
        else:
            other_neighbours = [nb for nb in self.neighbours if not nb == other]
            vectors = [self.in_msgs[nb] for nb in other_neighbours] + [self.observed_state]
            message = np.multiply.reduce(vectors)
        
        other.receive_msg(self, message)
        self.pending.remove(other)
        
        
    def send_ms_msg(self, other):
        # TODO: implement Variable -> Factor message for max-sum
        assert type(other) == Factor, "Other node needs to a be Factor, received {}".format(other)
        for nb in self.neighbours:
            if not nb == other:
                assert nb in self.in_msgs.keys(), "Missing message from variable {}".format(nb)
        # all messages present
        if len(self.neighbours) == 1:
            # leaf variable-node
            message = np.log(self.observed_state)
            
        else:
            other_neighbours = [nb for nb in self.neighbours if not nb == other]
            vectors = [self.in_msgs[nb] for nb in other_neighbours] + np.log([self.observed_state])
            message = np.add.reduce(vectors)
        
        other.receive_msg(self, message)
        self.pending.remove(other)

class Factor(Node):
    def __init__(self, name, f, neighbours):
        """
        Factor node constructor.
        Args:
            name: a name string for this node. Used for printing
            f: a numpy.ndarray with N axes, where N is the number of neighbours.
               That is, the axes of f correspond to variables, and the index along that axes corresponds to a value of that variable.
               Each axis of the array should have as many entries as the corresponding neighbour variable has states.
            neighbours: a list of neighbouring Variables. Bi-directional connections are created.
        """
        # Call the base-class constructor
        super(Factor, self).__init__(name)

        assert len(neighbours) == f.ndim, 'Factor function f should accept as many arguments as this Factor node has neighbours'
        
        for nb_ind in range(len(neighbours)):
            nb = neighbours[nb_ind]
            assert f.shape[nb_ind] == nb.num_states, 'The range of the factor function f is invalid for input %i %s' % (nb_ind, nb.name)
            self.add_neighbour(nb)
            nb.add_neighbour(self)

        self.f = f
        
    def send_sp_msg(self, other):
        # Factor -> Variable message for sum-product
        assert type(other) == Variable, "Other node needs to a be Variable, received {}".format(other)
        # check if necessary messages are present
        for nb in self.neighbours:
            if not nb == other:
                assert nb in self.in_msgs.keys(), "Missing message from variable {}".format(nb)
        # all messages present
        
        if len(self.neighbours) == 1:
            # leaf factor-node
            message = self.f
            
        else:
            other_neighbours = [nb for nb in self.neighbours if not nb == other]
            vectors = [self.in_msgs[nb] for nb in other_neighbours]
            product_mu = np.multiply.reduce(np.ix_(*vectors)) # is simply outer-product v1.v2^T if vectors = [v1, v2]
            other_i = self.neighbours.index(other) # the index of the variable to which we send the message
            f_axes = [i for i in range(len(self.neighbours)) if not i==other_i]
            message = np.tensordot(self.f, product_mu, axes=(f_axes, range(product_mu.ndim)))
        
        other.receive_msg(self, message)
        self.pending.remove(other)
       
    def send_ms_msg(self, other):
        # TODO: implement Factor -> Variable message for max-sum
        assert type(other) == Variable, "Other node needs to a be Variable, received {}".format(other)
        # check if necessary messages are present
        for nb in self.neighbours:
            if not nb == other:
                assert nb in self.in_msgs.keys(), "Missing message from variable {}".format(nb)
        # all messages present
        
        if len(self.neighbours) == 1:
            # leaf factor-node
            message = np.log(self.f)
        else:
            other_neighbours = [nb for nb in self.neighbours if not nb == other]
            vectors = [self.in_msgs[nb] for nb in other_neighbours]
            sum_mu = np.add.reduce(np.ix_(*vectors))
            other_i = self.neighbours.index(other) # the index of the variable to which we send the message
            f_axes = tuple((i for i in range(len(self.neighbours)) if not i==other_i))
            added = np.add(np.log(self.f), sum_mu)
            message = np.amax(added, axis=f_axes)
            
        other.receive_msg(self, message)
        self.pending.remove(other)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 1.1 Instantiate network (10 points)
# Convert the directed graphical model ("Bayesian Network") shown below to a factor graph. Instantiate this graph by creating Variable and Factor instances and linking them according to the graph structure.
# To instantiate the factor graph, first create the Variable nodes and then create Factor nodes, passing a list of neighbour Variables to each Factor.
# Use the following prior and conditional probabilities.
#
# $$
# p(\verb+Influenza+) = 0.05 \\\\
# p(\verb+Smokes+) = 0.2 \\\\
# $$
#
# $$
# p(\verb+SoreThroat+ = 1 | \verb+Influenza+ = 1) = 0.3 \\\\
# p(\verb+SoreThroat+ = 1 | \verb+Influenza+ = 0) = 0.001 \\\\
# p(\verb+Fever+ = 1| \verb+Influenza+ = 1) = 0.9 \\\\
# p(\verb+Fever+ = 1| \verb+Influenza+ = 0) = 0.05 \\\\
# p(\verb+Bronchitis+ = 1 | \verb+Influenza+ = 1, \verb+Smokes+ = 1) = 0.99 \\\\
# p(\verb+Bronchitis+ = 1 | \verb+Influenza+ = 1, \verb+Smokes+ = 0) = 0.9 \\\\
# p(\verb+Bronchitis+ = 1 | \verb+Influenza+ = 0, \verb+Smokes+ = 1) = 0.7 \\\\
# p(\verb+Bronchitis+ = 1 | \verb+Influenza+ = 0, \verb+Smokes+ = 0) = 0.0001 \\\\
# p(\verb+Coughing+ = 1| \verb+Bronchitis+ = 1) = 0.8 \\\\
# p(\verb+Coughing+ = 1| \verb+Bronchitis+ = 0) = 0.07 \\\\
# p(\verb+Wheezing+ = 1| \verb+Bronchitis+ = 1) = 0.6 \\\\
# p(\verb+Wheezing+ = 1| \verb+Bronchitis+ = 0) = 0.001 \\\\
# $$

# %%
from IPython.core.display import Image 
Image(filename='bn.png')

# %%
# YOUR ANSWER HERE

I = Variable('I', 2)
ST = Variable('ST', 2)
F = Variable('F', 2)
B = Variable('B', 2)
S = Variable('S', 2)
C = Variable('C', 2)
W = Variable('W', 2)

F_I = Factor('F_I', np.array([0.95, 0.05]), [I])
F_S = Factor('F_S', np.array([0.8, 0.2]), [S])

# I=0: [0.,0.001]; I=1: [0., 0.3] since f.shape[0]=I.num_states and f.shape[1]=.num_states[ST]
F_IST = Factor('F_IST', np.array([[0.999, 0.001], 
                                  [0.7, 0.3]]), [I, ST])

F_IF = Factor('F_IF', np.array([[0.1, 0.9], 
                                [0.95, 0.05]]), [I, F])

F_ISB = Factor('F_ISB', np.array([[[0.9999, 0.0001], 
                                   [0.3, 0.7]], 
                                  [[0.1, 0.9], 
                                   [0.01, 0.99]]]), [I, S, B])

F_BC = Factor('F_BC', np.array([[0.93, 0.07], 
                                [0.2, 0.8]]), [B, C])

F_BW = Factor('F_BW', np.array([[0.999, 0.001], 
                                [0.4, 0.6]]), [B, W])


def reset_nodes(variables):
    for v in variables:
        v.reset()

# %% [markdown]
# ### 1.2 Factor to variable messages (20 points)
# Write a method `send_sp_msg(self, other)` for the Factor class, that checks if all the information required to pass a message to Variable `other` is present, computes the message and sends it to `other`. "Sending" here simply means calling the `receive_msg` function of the receiving node (we will implement this later). The message itself should be represented as a numpy array (np.array) whose length is equal to the number of states of the variable.
#
# An elegant and efficient solution can be obtained using the n-way outer product of vectors. This product takes n vectors $\mathbf{x}^{(1)}, \ldots, \mathbf{x}^{(n)}$ and computes a $n$-dimensional tensor (ndarray) whose element $i_0,i_1,...,i_n$ is given by $\prod_j \mathbf{x}^{(j)}_{i_j}$. In python, this is realized as `np.multiply.reduce(np.ix_(*vectors))` for a python list `vectors` of 1D numpy arrays. Try to figure out how this statement works -- it contains some useful functional programming techniques. Another function that you may find useful in computing the message is `np.tensordot`.

# %%
# Trying to understand np.multiply.reduce(np.ix_(*vectors)):
# vectors = [np.array([i,i+1,i+2]) for i in range(1,4)]
vectors = [np.array([i,i+1]) for i in range(1,3)]
print(vectors)
print(*vectors)
# print([1,2,3],[2,3,4])
print(np.ix_(*vectors))
# print(np.ix_([1,2,3],[2,3,4]))
m = np.multiply.reduce(np.ix_(*vectors))
print(m)

print('\n')

# Trying to understand np.tensordot:
f = np.arange(8.).reshape(2,2,2)
print(f)
mu = np.array([[1,2],[2,4]])
print(mu)
c = np.tensordot(f, mu, axes=([1,2],[0,1]))
print(c)
# c.shape
# Out:
# [array([1, 2]), array([2, 3])]
# [1 2] [2 3]
# (array([[1],
#        [2]]), array([[2, 3]]))
# [[2 3]
#  [4 6]]
#
#
# [[[ 0.  1.]
#   [ 2.  3.]]
#
#  [[ 4.  5.]
#   [ 6.  7.]]]
# [[1 2]
#  [2 4]]
# [ 18.  54.]

# %%
# Test example working like the tensordot above:
F_ISB = Factor('F_ISB', np.array([[[0.9999, 0.0001], 
                                   [0.3, 0.7]], 
                                  [[0.1, 0.9], 
                                   [0.01, 0.99]]]), [I, S, B])
F_ISB.receive_msg(S, np.array([1, 2]))
F_ISB.receive_msg(B, np.array([3, 4]))
F_ISB.send_sp_msg(I)

A = np.array([[0.9999, 0.0001],[0.3, 0.7]])
B = np.array([[0.1, 0.9],[0.01, 0.99]])
C = np.array([[3, 4],[6, 8]])
print(np.sum(np.multiply(A, C)))
print(np.sum(np.multiply(B, C)))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-597-fc8b544856c6> in <module>()
#       6 F_ISB.receive_msg(S, np.array([1, 2]))
#       7 F_ISB.receive_msg(B, np.array([3, 4]))
# ----> 8 F_ISB.send_sp_msg(I)
#       9
#      10 A = np.array([[0.9999, 0.0001],[0.3, 0.7]])
#
# <ipython-input-596-4b7d21b6bb14> in send_sp_msg(self, other)
#     197     def send_sp_msg(self, other):
#     198         # Factor -> Variable message for sum-product
# --> 199         assert type(other) == Variable, "Other node needs to a be Variable, received {}".format(other)
#     200         # check if necessary messages are present
#     201         for nb in self.neighbours:
#
# AssertionError: Other node needs to a be Variable, received I

# %%
init_graph()
I.receive_msg(F_IST, np.array([1, 2]))
I.receive_msg(F_IF, np.array([1, 2]))
I.receive_msg(F_I, np.array([1, 2]))

I.send_sp_msg(F_ISB)

# %% [markdown]
# ### 1.3 Variable to factor messages (10 points)
#
# Write a method `send_sp_message(self, other)` for the Variable class, that checks if all the information required to pass a message to Variable var is present, computes the message and sends it to factor.

# %% [markdown]
# ### 1.4 Compute marginal (10 points)
# Later in this assignment, we will implement message passing schemes to do inference. Once the message passing has completed, we will want to compute local marginals for each variable.
# Write the method `marginal` for the Variable class, that computes a marginal distribution over that node.

# %%
I.receive_msg(F_IST, np.array([1, 2]))
I.receive_msg(F_IF, np.array([1, 2]))
I.receive_msg(F_I, np.array([1, 2]))
I.receive_msg(F_ISB, np.array([1, 2]))

I.marginal()
# Out:
# (array([ 0.05882353,  0.94117647]), 17.0)

# %% [markdown]
# ### 1.5 Receiving messages (10 points)
# In order to implement the loopy and non-loopy message passing algorithms, we need some way to determine which nodes are ready to send messages to which neighbours. To do this in a way that works for both loopy and non-loopy algorithms, we make use of the concept of "pending messages", which is explained in Bishop (8.4.7):
# "we will say that a (variable or factor)
# node a has a message pending on its link to a node b if node a has received any
# message on any of its other links since the last time it send (sic) a message to b. Thus,
# when a node receives a message on one of its links, this creates pending messages
# on all of its other links."
#
# Keep in mind that for the non-loopy algorithm, nodes may not have received any messages on some or all of their links. Therefore, before we say node a has a pending message for node b, we must check that node a has received all messages needed to compute the message that is to be sent to b.
#
# Modify the function `receive_msg`, so that it updates the self.pending variable as described above. The member self.pending is a set that is to be filled with Nodes to which self has pending messages. Modify the `send_msg` functions to remove pending messages as they are sent.

# %% [markdown]
# ### 1.6 Inference Engine (10 points)
# Write a function `sum_product(node_list)` that runs the sum-product message passing algorithm on a tree-structured factor graph with given nodes. The input parameter `node_list` is a list of all Node instances in the graph, which is assumed to be ordered correctly. That is, the list starts with a leaf node, which can always send a message. Subsequent nodes in `node_list` should be capable of sending a message when the pending messages of preceding nodes in the list have been sent. The sum-product algorithm then proceeds by passing over the list from beginning to end, sending all pending messages at the nodes it encounters. Then, in reverse order, the algorithm traverses the list again and again sends all pending messages at each node as it is encountered. For this to work, you must initialize pending messages for all the leaf nodes, e.g. `influenza_prior.pending.add(influenza)`, where `influenza_prior` is a Factor node corresponding the the prior, `influenza` is a Variable node and the only connection of `influenza_prior` goes to `influenza`.

# %%
variables = [I, ST, F, B, S, C, W]
node_list = [ST, F, F_I, F_S, C, W, F_IST, F_IF, S, I, F_ISB, F_BC, F_BW, B]

def init_nodes():
#     for v in variables:
#         v.reset()
    F_I.pending.add(I)
    F_S.pending.add(S)
    ST.pending.add(F_IST)
    F.pending.add(F_IF)
    C.pending.add(F_BC)
    W.pending.add(F_BW)

# def passing(node_list, sum_product=True):
#     for node in node_list:
# #         print('Pending for {}'.format(node))
# #         for i in node.pending: print('\t' + str(i))
#         for pending in list(node.pending):
# #             print('Sending from {0} to {1}'.format(node, pending))
#             if sum_product:
#                 node.send_sp_msg(pending)
#             else:
#                 node.send_ms_msg(pending)

def passing(node_list, sum_product=True):
    for node in node_list:
        print("Current node: {}".format(node))
        print('Pending:')
        print('\n'.join(['\t{}'.format(pending) for pending in node.pending]))
        for pending in list(node.pending):
            print('Sending from {0} to {1}'.format(node, pending))
            if sum_product:
                node.send_sp_msg(pending)
            else:
                node.send_ms_msg(pending)
            print('\n')

def sum_product(node_list):
    init_nodes()
    passing(node_list, sum_product=True)
    passing(reversed(node_list), sum_product=True)

# %%
init_graph()
sum_product(node_list)

print(I.marginal())
print(ST.marginal())
print(F.marginal())
print(C.marginal())
print(W.marginal())
# Out:
# Current node: ST
# Pending:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-761-4f9f8efcdd39> in <module>()
#       1 init_graph()
# ----> 2 sum_product(node_list)
#       3
#       4 print(I.marginal())
#       5 print(ST.marginal())
#
# <ipython-input-758-2e15032d4f4a> in sum_product(node_list)
#      38 def sum_product(node_list):
#      39     init_nodes()
# ---> 40     passing(node_list, sum_product=True)
#      41     passing(reversed(node_list), sum_product=True)
#
# <ipython-input-758-2e15032d4f4a> in passing(node_list, sum_product)
#      31             print('Sending from {0} to {1}'.format(node, pending))
#      32         if sum_product:
# ---> 33             node.send_sp_msg(pending)
#      34         else:
#      35             node.send_ms_msg(pending)
#
# UnboundLocalError: local variable 'pending' referenced before assignment

# %%
init_graph()
S.set_observed(1)
sum_product(node_list)
print(I.marginal())
print(ST.marginal())
print(F.marginal())
print(C.marginal())
print(W.marginal())
# Out:
# (array([ 0.95,  0.05]), 0.20000079999999998)
# (array([ 0.98405,  0.01595]), 0.20000079999999995)
# (array([ 0.1425,  0.8575]), 0.20000079999999995)
# (array([ 0.40841695,  0.59158305]), 0.20000079999999998)
# (array([ 0.5710161,  0.4289839]), 0.20000079999999998)

# %%
init_graph()
I.set_observed(0)
sum_product(node_list)
print(B.marginal())
# Out:
# (array([ 0.30000278,  0.69999722]), 0.19000077000003998)

# %%
init_graph()
I.set_observed(1)
sum_product(node_list)
print(B.marginal())
# Out:
# (array([ 0.01000587,  0.98999413]), 0.010000230000760002)

# %%
init_graph()
S.set_observed(0)
sum_product(node_list)
print(B.marginal())
# Out:
# (array([ 0.10001708,  0.89998292]), 0.040000770000190006)

# %%
init_graph()
S.set_observed(1)
I.set_observed(1)
sum_product(node_list)
print(B.marginal())
# Out:
# (array([ 0.01000587,  0.98999413]), 0.010000230000760002)

# %% [markdown]
# ### 1.7 Observed variables and probabilistic queries (15 points)
# We will now use the inference engine to answer probabilistic queries. That is, we will set certain variables to observed values, and obtain the marginals over latent variables. We have already provided functions `set_observed` and `set_latent` that manage a member of Variable called `observed_state`. Modify the `Variable.send_msg` and `Variable.marginal` routines that you wrote before, to use `observed_state` so as to get the required marginals when some nodes are observed.

# %% [markdown]
# ### 1.8 Sum-product and MAP states (5 points)
# A maximum a posteriori state (MAP-state) is an assignment of all latent variables that maximizes the probability of latent variables given observed variables:
# $$
# \mathbf{x}_{\verb+MAP+} = \arg\max _{\mathbf{x}} p(\mathbf{x} | \mathbf{y})
# $$
# Could we use the sum-product algorithm to obtain a MAP state? If yes, how? If no, why not?

# %% [markdown]
# __YOUR ANSWER HERE__

# %% [markdown]
# ## Part 2: The max-sum algorithm
# Next, we implement the max-sum algorithm as described in section 8.4.5 of Bishop.

# %% [markdown]
# ### 2.1 Factor to variable messages (10 points)
# Implement the function `Factor.send_ms_msg` that sends Factor -> Variable messages for the max-sum algorithm. It is analogous to the `Factor.send_sp_msg` function you implemented before.

# %%
# testing
F_ISB = Factor('F_ISB', np.array([[[1, 2], 
                                   [3, 4]], 
                                  [[5, 6], 
                                   [7, 8]]]), [I, S, B])
F_ISB.receive_msg(S, np.array([1, 2]))
F_ISB.receive_msg(B, np.array([2, 3]))
F_ISB.send_ms_msg(I)
# Out:
# [[[ 0.          0.69314718]
#   [ 1.09861229  1.38629436]]
#
#  [[ 1.60943791  1.79175947]
#   [ 1.94591015  2.07944154]]]
# [[3 4]
#  [4 5]]
# [ 6.38629436  7.07944154]

# %%
f = np.log(np.arange(1,9.).reshape(2,2,2))
print(f)
vectors = [[1,2],[2,3]]
mu = np.add.reduce(np.ix_(*vectors))
print(mu)
c = np.add(f, mu)
print(c)
print(np.amax(c, axis=(1,2)))
# Out:
# [[[ 0.          0.69314718]
#   [ 1.09861229  1.38629436]]
#
#  [[ 1.60943791  1.79175947]
#   [ 1.94591015  2.07944154]]]
# [[3 4]
#  [4 5]]
# [[[ 3.          4.69314718]
#   [ 5.09861229  6.38629436]]
#
#  [[ 4.60943791  5.79175947]
#   [ 5.94591015  7.07944154]]]
# [ 6.38629436  7.07944154]

# %% [markdown]
# ### 2.2 Variable to factor messages (10 points)
# Implement the `Variable.send_ms_msg` function that sends Variable -> Factor messages for the max-sum algorithm.

# %% [markdown]
# ### 2.3 Find a MAP state (10 points)
#
# Using the same message passing schedule we used for sum-product, implement the max-sum algorithm. For simplicity, we will ignore issues relating to non-unique maxima. So there is no need to implement backtracking; the MAP state is obtained by a per-node maximization (eq. 8.98 in Bishop). Make sure your algorithm works with both latent and observed variables.

# %%
# YOUR ANSWER HERE

# def init_graph():
I = Variable('I', 2)
ST = Variable('ST', 2)
F = Variable('F', 2)
B = Variable('B', 2)
S = Variable('S', 2)
C = Variable('C', 2)
W = Variable('W', 2)

F_I = Factor('F_I', np.array([0.95, 0.05]), [I])
F_S = Factor('F_S', np.array([0.8, 0.2]), [S])

# I=0: [0.,0.001]; I=1: [0., 0.3] since f.shape[0]=I.num_states and f.shape[1]=.num_states[ST]
F_IST = Factor('F_IST', np.array([[0.999, 0.001], 
                                  [0.7, 0.3]]), [I, ST])

F_IF = Factor('F_IF', np.array([[0.1, 0.9], 
                                [0.95, 0.05]]), [I, F])

F_ISB = Factor('F_ISB', np.array([[[0.9999, 0.0001], 
                                   [0.3, 0.7]], 
                                  [[0.1, 0.9], 
                                   [0.01, 0.99]]]), [I, S, B])

F_BC = Factor('F_BC', np.array([[0.93, 0.07], 
                                [0.2, 0.8]]), [B, C])

F_BW = Factor('F_BW', np.array([[0.999, 0.001], 
                                [0.4, 0.6]]), [B, W])

# %%
def MAP_state(node):
    mus = [node.in_msgs[nb] for nb in node.neighbours] + np.log(node.observed_state)
    return np.argmax(np.add.reduce(mus))
    
def max_sum(node_list):
    passing(node_list, sum_product=False)
    passing(reversed(node_list), sum_product=False)
    
def print_MAP(variables):
    print('\n'.join(['{0}: {1}'.format(node, MAP_state(node)) for node in variables]))

# %%
variables = [I, ST, F, B, S, C, W]
node_list = [ST, F, F_I, F_S, C, W, F_IST, F_IF, S, I, F_ISB, F_BC, F_BW, B]

init_nodes()
max_sum(node_list)
print_MAP(variables)
# Out:
# Current node: ST
# Pending:
# 	F_IST
# Sending from ST to F_IST
#
#
# Current node: F
# Pending:
# 	F_IF
# Sending from F to F_IF
#
#
# Current node: F_I
# Pending:
# 	I
# Sending from F_I to I
#
#
# Current node: F_S
# Pending:
# 	S
# Sending from F_S to S
#
#
# Current node: C
# Pending:
# 	F_BC
# Sending from C to F_BC
#
#
# Current node: W
# Pending:
# 	F_BW
# Sending from W to F_BW
#
#
# Current node: F_IST
# Pending:
# 	I
# Sending from F_IST to I
#
#
# Current node: F_IF
# Pending:
# 	I
# Sending from F_IF to I
#
#
# Current node: S
# Pending:
# 	F_ISB
# Sending from S to F_ISB
#
#
# Current node: I
# Pending:
# 	F_ISB
# Sending from I to F_ISB
#
#
# Current node: F_ISB
# Pending:
# 	B
# Sending from F_ISB to B
#
#
# Current node: F_BC
# Pending:
# 	B
# Sending from F_BC to B
#
#
# Current node: F_BW
# Pending:
# 	B
# Sending from F_BW to B
#
#
# Current node: B
# Pending:
# 	F_ISB
# 	F_BW
# 	F_BC
# Sending from B to F_ISB
#
#
# Sending from B to F_BW
#
#
# Sending from B to F_BC
#
#
# Current node: B
# Pending:
#
# Current node: F_BW
# Pending:
# 	W
# Sending from F_BW to W
#
#
# Current node: F_BC
# Pending:
# 	C
# Sending from F_BC to C
#
#
# Current node: F_ISB
# Pending:
# 	I
# 	S
# Sending from F_ISB to I
#
#
# Sending from F_ISB to S
#
#
# Current node: I
# Pending:
# 	F_IST
# 	F_IF
# 	F_I
# Sending from I to F_IST
#
#
# Sending from I to F_IF
#
#
# Sending from I to F_I
#
#
# Current node: S
# Pending:
# 	F_S
# Sending from S to F_S
#
#
# Current node: F_IF
# Pending:
# 	F
# Sending from F_IF to F
#
#
# Current node: F_IST
# Pending:
# 	ST
# Sending from F_IST to ST
#
#
# Current node: W
# Pending:
#
# Current node: C
# Pending:
#
# Current node: F_S
# Pending:
#
# Current node: F_I
# Pending:
#
# Current node: F
# Pending:
#
# Current node: ST
# Pending:
#
# I: 0
# ST: 0
# F: 0
# B: 0
# S: 0
# C: 0
# W: 0

# %%
variables = [I, ST, F, B, S, C, W]
node_list = [ST, F, F_I, F_S, C, W, F_IST, F_IF, S, I, F_ISB, F_BC, F_BW, B]

init_nodes()
I.set_observed(1)
max_sum(node_list)
print_MAP(variables)
# Out:
# Current node: ST
# Pending:
# 	F_IST
# Sending from ST to F_IST
#
#
# Current node: F
# Pending:
# 	F_IF
# Sending from F to F_IF
#
#
# Current node: F_I
# Pending:
# 	I
# Sending from F_I to I
#
#
# Current node: F_S
# Pending:
# 	S
# Sending from F_S to S
#
#
# Current node: C
# Pending:
# 	F_BC
# Sending from C to F_BC
#
#
# Current node: W
# Pending:
# 	F_BW
# Sending from W to F_BW
#
#
# Current node: F_IST
# Pending:
# 	I
# Sending from F_IST to I
#
#
# Current node: F_IF
# Pending:
# 	I
# Sending from F_IF to I
#
#
# Current node: S
# Pending:
# 	F_ISB
# Sending from S to F_ISB
#
#
# Current node: I
# Pending:
# 	F_ISB
# Sending from I to F_ISB
#
#
# Current node: F_ISB
# Pending:
# 	B
# Sending from F_ISB to B
#
#
# Current node: F_BC
# Pending:
# 	B
# Sending from F_BC to B
#
#
# Current node: F_BW
# Pending:
# 	B
# Sending from F_BW to B
#
#
# Current node: B
# Pending:
# 	F_BC
# 	F_BW
# 	F_ISB
# Sending from B to F_BC
#
#
# Sending from B to F_BW
#
#
# Sending from B to F_ISB
#
#
# Current node: B
# Pending:
#
# Current node: F_BW
# Pending:
# 	W
# Sending from F_BW to W
#
#
# Current node: F_BC
# Pending:
# 	C
# Sending from F_BC to C
#
#
# Current node: F_ISB
# Pending:
# 	S
# 	I
# Sending from F_ISB to S
#
#
# Sending from F_ISB to I
#
#
# Current node: I
# Pending:
# 	F_IF
# 	F_IST
# 	F_I
# Sending from I to F_IF
#
#
# Sending from I to F_IST
#
#
# Sending from I to F_I
#
#
# Current node: S
# Pending:
# 	F_S
# Sending from S to F_S
#
#
# Current node: F_IF
# Pending:
# 	F
# Sending from F_IF to F
#
#
# Current node: F_IST
# Pending:
# 	ST
# Sending from F_IST to ST
#
#
# Current node: W
# Pending:
#
# Current node: C
# Pending:
#
# Current node: F_S
# Pending:
#
# Current node: F_I
# Pending:
#
# Current node: F
# Pending:
#
# Current node: ST
# Pending:
#
# I: 1
# ST: 1
# F: 1
# B: 0
# S: 1
# C: 0
# W: 0

# %%
variables = [I, ST, F, B, S, C, W]
node_list = [ST, F, F_I, F_S, C, W, F_IST, F_IF, S, I, F_ISB, F_BC, F_BW, B]

init_nodes()
S.set_observed(1)
max_sum(node_list)
print_MAP(variables)
# Out:
# I: 0
# ST: 0
# F: 0
# B: 1
# S: 1
# C: 1
# W: 1

# %%
init_nodes()
I.set_observed(1)
S.set_observed(1)
max_sum(node_list)
print_MAP(variables)
# Out:
# I: 1
# ST: 1
# F: 1
# B: 1
# S: 1
# C: 1
# W: 1

# %%
variables = [I, ST, F, B, S, C, W]
node_list = [ST, F, F_I, F_S, C, W, F_IST, F_IF, S, I, F_ISB, F_BC, F_BW, B]

init_nodes()
C.set_observed(1)
W.set_observed(1)
max_sum(node_list)
print_MAP(variables)
# Out:
# I: 1
# ST: 1
# F: 1
# B: 1
# S: 1
# C: 1
# W: 1

# %% [markdown]
# ## Part 3: Image Denoising and Loopy BP
#
# Next, we will use a loopy version of max-sum to perform denoising on a binary image. The model itself is discussed in Bishop 8.3.3, but we will use loopy max-sum instead of Iterative Conditional Modes as Bishop does.
#
# The following code creates some toy data: `im` is a quite large binary image and `test_im` is a smaller synthetic binary image. Noisy versions are also provided.

# %%
from pylab import imread, gray
# Load the image and binarize
im = np.mean(imread('dalmatian1.png'), axis=2) > 0.5
imshow(im)
gray()

# Add some noise
noise = np.random.rand(*im.shape) > 0.9
noise_im = np.logical_xor(noise, im)
figure()
imshow(noise_im)

test_im = np.zeros((10,10))
#test_im[5:8, 3:8] = 1.0
#test_im[5,5] = 1.0
figure()
imshow(test_im)

# Add some noise
noise = np.random.rand(*test_im.shape) > 0.9
noise_test_im = np.logical_xor(noise, test_im)
figure()
imshow(noise_test_im)

# %% [markdown]
# ### 3.1 Construct factor graph (10 points)
# Convert the Markov Random Field (Bishop, fig. 8.31) to a factor graph and instantiate it.

# %%
# YOUR ANSWER HERE
from collections import defaultdict

class MRF:
    def __init__(self, image):
        self.image = image
        self.m = self.image.shape[0]
        self.n = self.image.shape[1]
        self.y_variables = numpy.array([[Variable]*self.n]*self.m, dtype=Variable)
        self.x_variables = numpy.array([[Variable]*self.n]*self.m, dtype=Variable)
        self.xx_factors = defaultdict(Factor)
        self.xy_factors = defaultdict(Factor)
    
    def make_graph(self, flipping=0.1, similar=0.6):
        # make ys, xs and 
        for i in range(self.m):
            for j in range(self.n):
                # make y
                y = Variable('Y-{}'.format((i,j)), 2)
                y.set_observed(int(self.image[i,j]))
                self.y_variables[i,j] = y
                # make x
                x = Variable('X-{}'.format((i,j)), 2)
                self.x_variables[i,j] = x
                # make correlation-factor x-y
                self.xy_factors[x, y] = Factor('Fxy-{}'.format((i,j)), 
                                                       np.array([[1-flipping, flipping], 
                                                                  [flipping, 1-flipping]]), 
                                                       [x, y])
        # make xij-xij+1 factors
        for i in range(self.m):
            for j in range(self.n-1):
                x_left = self.x_variables[i,j]
                x_right = self.x_variables[i,j+1]
                self.xx_factors[x_left, x_right] = Factor('Fxx-({0},{1}-{2})'.format(i,j,j+1), 
                                                       np.array([[similar, 1-similar], 
                                                                  [1-similar, similar]]), 
                                                       [x_left, x_right])
        # make xij-xi+1j factors
        for j in range(self.n):
            for i in range(self.m-1):
                x_top = self.x_variables[(i,j)]
                x_bottom = self.x_variables[(i+1,j)]
                self.xx_factors[x_top, x_bottom] = Factor('Fxx-({0}-{1},{2})'.format(i,i+1,j), 
                                                       np.array([[similar, 1-similar], 
                                                                  [1-similar, similar]]), 
                                                       [x_top, x_bottom])
 
    
    def passing(self, node_list):
        for node in node_list:
            print("Current node: {}".format(node))
            print('Pending:')
            print('\n'.join(['\t{}'.format(pending) for pending in node.pending]))
            for pending in list(node.pending):
                print('Sending from {0} to {1}'.format(node, pending))
                node.send_ms_msg(pending)
            print('\n')
    
    def initialize_messages(self, node_list):
        for node in node_list:
            for neighbour in node.neighbours:
                if type(neighbour) == Variable:
                    node.in_msgs[neighbour] = np.zeros(neighbour.num_states)
                    node.pending.update({neighbour})
                else:
                    node.in_msgs[neighbour] = np.zeros(node.num_states)
                    node.pending.update({neighbour})            
            
    def max_sum(self, iterations=1):

        def set_y_peding():
            for i in range(self.m):
                for j in range(self.n):
                    y = self.y_variables[i,j]
                    x = self.x_variables[i,j]
                    factor = self.xy_factors[x, y]
                    y.pending.add(factor)
                    
#         def send_pending(node):
# #             print("Current node: {}".format(node))
# #             print('Pending:')
# #             print('\n'.join(['\t{}'.format(pending) for pending in node.pending]))
#             for pending in list(node.pending):
# #                 print('Sending from {0} to {1}'.format(node, pending))
#                 node.send_ms_msg(pending)
# #             print('\n')
        
        flat_y = self.y_variables.flatten()
        flat_x = self.x_variables.flatten()
        xy_factors = np.array([factor for factor in self.xy_factors.values()])
        xx_factors = np.array([factor for factor in self.xx_factors.values()])
        
        one_way = concatenate((flat_y, xy_factors, flat_x, xx_factors))
        other_way = reversed(concatenate((flat_y, xy_factors, flat_x)))

        # initialize messages
        self.initialize_messages(one_way)
        
        for i in range(iterations):
            set_y_peding()
            self.passing(one_way)
            self.passing(other_way)

    def denoised(self):
        denoised = np.zeros((self.m, self.n))
        
        def MAP_state(node):
            mus = [node.in_msgs[nb] for nb in node.neighbours] + np.log(node.observed_state)
            return np.argmax(np.add.reduce(mus))
        
        for i in range(self.m):
            for j in range(self.n):
                x = self.x_variables[i,j]
                denoised[i,j] = MAP_state(x)
        return denoised

# %%
mrf = MRF(noise_test_im)
mrf.make_graph(flipping=0.1, similar=0.9)
mrf.max_sum(iterations=1)

denoised = mrf.denoised()
# Out:
# Current node: Y-(0, 0)
# Pending:
# 	Fxy-(0, 0)
# Sending from Y-(0, 0) to Fxy-(0, 0)
#
#
# Current node: Y-(0, 1)
# Pending:
# 	Fxy-(0, 1)
# Sending from Y-(0, 1) to Fxy-(0, 1)
#
#
# Current node: Y-(0, 2)
# Pending:
# 	Fxy-(0, 2)
# Sending from Y-(0, 2) to Fxy-(0, 2)
#
#
# Current node: Y-(0, 3)
# Pending:
# 	Fxy-(0, 3)
# Sending from Y-(0, 3) to Fxy-(0, 3)
#
#
# Current node: Y-(0, 4)
# Pending:
# 	Fxy-(0, 4)
# Sending from Y-(0, 4) to Fxy-(0, 4)
#
#
# Current node: Y-(0, 5)
# Pending:
# 	Fxy-(0, 5)
# Sending from Y-(0, 5) to Fxy-(0, 5)
#
#
# Current node: Y-(0, 6)
# Pending:
# 	Fxy-(0, 6)
# Sending from Y-(0, 6) to Fxy-(0, 6)
#
#
# Current node: Y-(0, 7)
# Pending:
# 	Fxy-(0, 7)
# Sending from Y-(0, 7) to Fxy-(0, 7)
#
#
# Current node: Y-(0, 8)
# Pending:
# 	Fxy-(0, 8)
# Sending from Y-(0, 8) to Fxy-(0, 8)
#
#
# Current node: Y-(0, 9)
# Pending:
# 	Fxy-(0, 9)
# Sending from Y-(0, 9) to Fxy-(0, 9)
#
#
# Current node: Y-(1, 0)
# Pending:
# 	Fxy-(1, 0)
# Sending from Y-(1, 0) to Fxy-(1, 0)
#
#
# Current node: Y-(1, 1)
# Pending:
# 	Fxy-(1, 1)
# Sending from Y-(1, 1) to Fxy-(1, 1)
#
#
# Current node: Y-(1, 2)
# Pending:
# 	Fxy-(1, 2)
# Sending from Y-(1, 2) to Fxy-(1, 2)
#
#
# Current node: Y-(1, 3)
# Pending:
# 	Fxy-(1, 3)
# Sending from Y-(1, 3) to Fxy-(1, 3)
#
#
# Current node: Y-(1, 4)
# Pending:
# 	Fxy-(1, 4)
# Sending from Y-(1, 4) to Fxy-(1, 4)
#
#
# Current node: Y-(1, 5)
# Pending:
# 	Fxy-(1, 5)
# Sending from Y-(1, 5) to Fxy-(1, 5)
#
#
# Current node: Y-(1, 6)
# Pending:
# 	Fxy-(1, 6)
# Sending from Y-(1, 6) to Fxy-(1, 6)
#
#
# Current node: Y-(1, 7)
# Pending:
# 	Fxy-(1, 7)
# Sending from Y-(1, 7) to Fxy-(1, 7)
#
#
# Current node: Y-(1, 8)
# Pending:
# 	Fxy-(1, 8)
# Sending from Y-(1, 8) to Fxy-(1, 8)
#
#
# Current node: Y-(1, 9)
# Pending:
# 	Fxy-(1, 9)
# Sending from Y-(1, 9) to Fxy-(1, 9)
#
#
# Current node: Y-(2, 0)
# Pending:
# 	Fxy-(2, 0)
# Sending from Y-(2, 0) to Fxy-(2, 0)
#
#
# Current node: Y-(2, 1)
# Pending:
# 	Fxy-(2, 1)
# Sending from Y-(2, 1) to Fxy-(2, 1)
#
#
# Current node: Y-(2, 2)
# Pending:
# 	Fxy-(2, 2)
# Sending from Y-(2, 2) to Fxy-(2, 2)
#
#
# Current node: Y-(2, 3)
# Pending:
# 	Fxy-(2, 3)
# Sending from Y-(2, 3) to Fxy-(2, 3)
#
#
# Current node: Y-(2, 4)
# Pending:
# 	Fxy-(2, 4)
# Sending from Y-(2, 4) to Fxy-(2, 4)
#
#
# Current node: Y-(2, 5)
# Pending:
# 	Fxy-(2, 5)
# Sending from Y-(2, 5) to Fxy-(2, 5)
#
#
# Current node: Y-(2, 6)
# Pending:
# 	Fxy-(2, 6)
# Sending from Y-(2, 6) to Fxy-(2, 6)
#
#
# Current node: Y-(2, 7)
# Pending:
# 	Fxy-(2, 7)
# Sending from Y-(2, 7) to Fxy-(2, 7)
#
#
# Current node: Y-(2, 8)
# Pending:
# 	Fxy-(2, 8)
# Sending from Y-(2, 8) to Fxy-(2, 8)
#
#
# Current node: Y-(2, 9)
# Pending:
# 	Fxy-(2, 9)
# Sending from Y-(2, 9) to Fxy-(2, 9)
#
#
# Current node: Y-(3, 0)
# Pending:
# 	Fxy-(3, 0)
# Sending from Y-(3, 0) to Fxy-(3, 0)
#
#
# Current node: Y-(3, 1)
# Pending:
# 	Fxy-(3, 1)
# Sending from Y-(3, 1) to Fxy-(3, 1)
#
#
# Current node: Y-(3, 2)
# Pending:
# 	Fxy-(3, 2)
# Sending from Y-(3, 2) to Fxy-(3, 2)
#
#
# Current node: Y-(3, 3)
# Pending:
# 	Fxy-(3, 3)
# Sending from Y-(3, 3) to Fxy-(3, 3)
#
#
# Current node: Y-(3, 4)
# Pending:
# 	Fxy-(3, 4)
# Sending from Y-(3, 4) to Fxy-(3, 4)
#
#
# Current node: Y-(3, 5)
# Pending:
# 	Fxy-(3, 5)
# Sending from Y-(3, 5) to Fxy-(3, 5)
#
#
# Current node: Y-(3, 6)
# Pending:
# 	Fxy-(3, 6)
# Sending from Y-(3, 6) to Fxy-(3, 6)
#
#
# Current node: Y-(3, 7)
# Pending:
# 	Fxy-(3, 7)
# Sending from Y-(3, 7) to Fxy-(3, 7)
#
#
# Current node: Y-(3, 8)
# Pending:
# 	Fxy-(3, 8)
# Sending from Y-(3, 8) to Fxy-(3, 8)
#
#
# Current node: Y-(3, 9)
# Pending:
# 	Fxy-(3, 9)
# Sending from Y-(3, 9) to Fxy-(3, 9)
#
#
# Current node: Y-(4, 0)
# Pending:
# 	Fxy-(4, 0)
# Sending from Y-(4, 0) to Fxy-(4, 0)
#
#
# Current node: Y-(4, 1)
# Pending:
# 	Fxy-(4, 1)
# Sending from Y-(4, 1) to Fxy-(4, 1)
#
#
# Current node: Y-(4, 2)
# Pending:
# 	Fxy-(4, 2)
# Sending from Y-(4, 2) to Fxy-(4, 2)
#
#
# Current node: Y-(4, 3)
# Pending:
# 	Fxy-(4, 3)
# Sending from Y-(4, 3) to Fxy-(4, 3)
#
#
# Current node: Y-(4, 4)
# Pending:
# 	Fxy-(4, 4)
# Sending from Y-(4, 4) to Fxy-(4, 4)
#
#
# Current node: Y-(4, 5)
# Pending:
# 	Fxy-(4, 5)
# Sending from Y-(4, 5) to Fxy-(4, 5)
#
#
# Current node: Y-(4, 6)
# Pending:
# 	Fxy-(4, 6)
# Sending from Y-(4, 6) to Fxy-(4, 6)
#
#
# Current node: Y-(4, 7)
# Pending:
# 	Fxy-(4, 7)
# Sending from Y-(4, 7) to Fxy-(4, 7)
#
#
# Current node: Y-(4, 8)
# Pending:
# 	Fxy-(4, 8)
# Sending from Y-(4, 8) to Fxy-(4, 8)
#
#
# Current node: Y-(4, 9)
# Pending:
# 	Fxy-(4, 9)
# Sending from Y-(4, 9) to Fxy-(4, 9)
#
#
# Current node: Y-(5, 0)
# Pending:
# 	Fxy-(5, 0)
# Sending from Y-(5, 0) to Fxy-(5, 0)
#
#
# Current node: Y-(5, 1)
# Pending:
# 	Fxy-(5, 1)
# Sending from Y-(5, 1) to Fxy-(5, 1)
#
#
# Current node: Y-(5, 2)
# Pending:
# 	Fxy-(5, 2)
# Sending from Y-(5, 2) to Fxy-(5, 2)
#
#
# Current node: Y-(5, 3)
# Pending:
# 	Fxy-(5, 3)
# Sending from Y-(5, 3) to Fxy-(5, 3)
#
#
# Current node: Y-(5, 4)
# Pending:
# 	Fxy-(5, 4)
# Sending from Y-(5, 4) to Fxy-(5, 4)
#
#
# Current node: Y-(5, 5)
# Pending:
# 	Fxy-(5, 5)
# Sending from Y-(5, 5) to Fxy-(5, 5)
#
#
# Current node: Y-(5, 6)
# Pending:
# 	Fxy-(5, 6)
# Sending from Y-(5, 6) to Fxy-(5, 6)
#
#
# Current node: Y-(5, 7)
# Pending:
# 	Fxy-(5, 7)
# Sending from Y-(5, 7) to Fxy-(5, 7)
#
#
# Current node: Y-(5, 8)
# Pending:
# 	Fxy-(5, 8)
# Sending from Y-(5, 8) to Fxy-(5, 8)
#
#
# Current node: Y-(5, 9)
# Pending:
# 	Fxy-(5, 9)
# Sending from Y-(5, 9) to Fxy-(5, 9)
#
#
# Current node: Y-(6, 0)
# Pending:
# 	Fxy-(6, 0)
# Sending from Y-(6, 0) to Fxy-(6, 0)
#
#
# Current node: Y-(6, 1)
# Pending:
# 	Fxy-(6, 1)
# Sending from Y-(6, 1) to Fxy-(6, 1)
#
#
# Current node: Y-(6, 2)
# Pending:
# 	Fxy-(6, 2)
# Sending from Y-(6, 2) to Fxy-(6, 2)
#
#
# Current node: Y-(6, 3)
# Pending:
# 	Fxy-(6, 3)
# Sending from Y-(6, 3) to Fxy-(6, 3)
#
#
# Current node: Y-(6, 4)
# Pending:
# 	Fxy-(6, 4)
# Sending from Y-(6, 4) to Fxy-(6, 4)
#
#
# Current node: Y-(6, 5)
# Pending:
# 	Fxy-(6, 5)
# Sending from Y-(6, 5) to Fxy-(6, 5)
#
#
# Current node: Y-(6, 6)
# Pending:
# 	Fxy-(6, 6)
# Sending from Y-(6, 6) to Fxy-(6, 6)
#
#
# Current node: Y-(6, 7)
# Pending:
# 	Fxy-(6, 7)
# Sending from Y-(6, 7) to Fxy-(6, 7)
#
#
# Current node: Y-(6, 8)
# Pending:
# 	Fxy-(6, 8)
# Sending from Y-(6, 8) to Fxy-(6, 8)
#
#
# Current node: Y-(6, 9)
# Pending:
# 	Fxy-(6, 9)
# Sending from Y-(6, 9) to Fxy-(6, 9)
#
#
# Current node: Y-(7, 0)
# Pending:
# 	Fxy-(7, 0)
# Sending from Y-(7, 0) to Fxy-(7, 0)
#
#
# Current node: Y-(7, 1)
# Pending:
# 	Fxy-(7, 1)
# Sending from Y-(7, 1) to Fxy-(7, 1)
#
#
# Current node: Y-(7, 2)
# Pending:
# 	Fxy-(7, 2)
# Sending from Y-(7, 2) to Fxy-(7, 2)
#
#
# Current node: Y-(7, 3)
# Pending:
# 	Fxy-(7, 3)
# Sending from Y-(7, 3) to Fxy-(7, 3)
#
#
# Current node: Y-(7, 4)
# Pending:
# 	Fxy-(7, 4)
# Sending from Y-(7, 4) to Fxy-(7, 4)
#
#
# Current node: Y-(7, 5)
# Pending:
# 	Fxy-(7, 5)
# Sending from Y-(7, 5) to Fxy-(7, 5)
#
#
# Current node: Y-(7, 6)
# Pending:
# 	Fxy-(7, 6)
# Sending from Y-(7, 6) to Fxy-(7, 6)
#
#
# Current node: Y-(7, 7)
# Pending:
# 	Fxy-(7, 7)
# Sending from Y-(7, 7) to Fxy-(7, 7)
#
#
# Current node: Y-(7, 8)
# Pending:
# 	Fxy-(7, 8)
# Sending from Y-(7, 8) to Fxy-(7, 8)
#
#
# Current node: Y-(7, 9)
# Pending:
# 	Fxy-(7, 9)
# Sending from Y-(7, 9) to Fxy-(7, 9)
#
#
# Current node: Y-(8, 0)
# Pending:
# 	Fxy-(8, 0)
# Sending from Y-(8, 0) to Fxy-(8, 0)
#
#
# Current node: Y-(8, 1)
# Pending:
# 	Fxy-(8, 1)
# Sending from Y-(8, 1) to Fxy-(8, 1)
#
#
# Current node: Y-(8, 2)
# Pending:
# 	Fxy-(8, 2)
# Sending from Y-(8, 2) to Fxy-(8, 2)
#
#
# Current node: Y-(8, 3)
# Pending:
# 	Fxy-(8, 3)
# Sending from Y-(8, 3) to Fxy-(8, 3)
#
#
# Current node: Y-(8, 4)
# Pending:
# 	Fxy-(8, 4)
# Sending from Y-(8, 4) to Fxy-(8, 4)
#
#
# Current node: Y-(8, 5)
# Pending:
# 	Fxy-(8, 5)
# Sending from Y-(8, 5) to Fxy-(8, 5)
#
#
# Current node: Y-(8, 6)
# Pending:
# 	Fxy-(8, 6)
# Sending from Y-(8, 6) to Fxy-(8, 6)
#
#
# Current node: Y-(8, 7)
# Pending:
# 	Fxy-(8, 7)
# Sending from Y-(8, 7) to Fxy-(8, 7)
#
#
# Current node: Y-(8, 8)
# Pending:
# 	Fxy-(8, 8)
# Sending from Y-(8, 8) to Fxy-(8, 8)
#
#
# Current node: Y-(8, 9)
# Pending:
# 	Fxy-(8, 9)
# Sending from Y-(8, 9) to Fxy-(8, 9)
#
#
# Current node: Y-(9, 0)
# Pending:
# 	Fxy-(9, 0)
# Sending from Y-(9, 0) to Fxy-(9, 0)
#
#
# Current node: Y-(9, 1)
# Pending:
# 	Fxy-(9, 1)
# Sending from Y-(9, 1) to Fxy-(9, 1)
#
#
# Current node: Y-(9, 2)
# Pending:
# 	Fxy-(9, 2)
# Sending from Y-(9, 2) to Fxy-(9, 2)
#
#
# Current node: Y-(9, 3)
# Pending:
# 	Fxy-(9, 3)
# Sending from Y-(9, 3) to Fxy-(9, 3)
#
#
# Current node: Y-(9, 4)
# Pending:
# 	Fxy-(9, 4)
# Sending from Y-(9, 4) to Fxy-(9, 4)
#
#
# Current node: Y-(9, 5)
# Pending:
# 	Fxy-(9, 5)
# Sending from Y-(9, 5) to Fxy-(9, 5)
#
#
# Current node: Y-(9, 6)
# Pending:
# 	Fxy-(9, 6)
# Sending from Y-(9, 6) to Fxy-(9, 6)
#
#
# Current node: Y-(9, 7)
# Pending:
# 	Fxy-(9, 7)
# Sending from Y-(9, 7) to Fxy-(9, 7)
#
#
# Current node: Y-(9, 8)
# Pending:
# 	Fxy-(9, 8)
# Sending from Y-(9, 8) to Fxy-(9, 8)
#
#
# Current node: Y-(9, 9)
# Pending:
# 	Fxy-(9, 9)
# Sending from Y-(9, 9) to Fxy-(9, 9)
#
#
# Current node: Fxy-(0, 0)
# Pending:
# 	Y-(0, 0)
# 	X-(0, 0)
# Sending from Fxy-(0, 0) to Y-(0, 0)
# Sending from Fxy-(0, 0) to X-(0, 0)
#
#
# Current node: Fxy-(0, 1)
# Pending:
# 	Y-(0, 1)
# 	X-(0, 1)
# Sending from Fxy-(0, 1) to Y-(0, 1)
# Sending from Fxy-(0, 1) to X-(0, 1)
#
#
# Current node: Fxy-(0, 2)
# Pending:
# 	Y-(0, 2)
# 	X-(0, 2)
# Sending from Fxy-(0, 2) to Y-(0, 2)
# Sending from Fxy-(0, 2) to X-(0, 2)
#
#
# Current node: Fxy-(0, 3)
# Pending:
# 	X-(0, 3)
# 	Y-(0, 3)
# Sending from Fxy-(0, 3) to X-(0, 3)
# Sending from Fxy-(0, 3) to Y-(0, 3)
#
#
# Current node: Fxy-(0, 4)
# Pending:
# 	Y-(0, 4)
# 	X-(0, 4)
# Sending from Fxy-(0, 4) to Y-(0, 4)
# Sending from Fxy-(0, 4) to X-(0, 4)
#
#
# Current node: Fxy-(0, 5)
# Pending:
# 	Y-(0, 5)
# 	X-(0, 5)
# Sending from Fxy-(0, 5) to Y-(0, 5)
# Sending from Fxy-(0, 5) to X-(0, 5)
#
#
# Current node: Fxy-(0, 6)
# Pending:
# 	Y-(0, 6)
# 	X-(0, 6)
# Sending from Fxy-(0, 6) to Y-(0, 6)
# Sending from Fxy-(0, 6) to X-(0, 6)
#
#
# Current node: Fxy-(0, 7)
# Pending:
# 	Y-(0, 7)
# 	X-(0, 7)
# Sending from Fxy-(0, 7) to Y-(0, 7)
# Sending from Fxy-(0, 7) to X-(0, 7)
#
#
# Current node: Fxy-(0, 8)
# Pending:
# 	X-(0, 8)
# 	Y-(0, 8)
# Sending from Fxy-(0, 8) to X-(0, 8)
# Sending from Fxy-(0, 8) to Y-(0, 8)
#
#
# Current node: Fxy-(0, 9)
# Pending:
# 	X-(0, 9)
# 	Y-(0, 9)
# Sending from Fxy-(0, 9) to X-(0, 9)
# Sending from Fxy-(0, 9) to Y-(0, 9)
#
#
# Current node: Fxy-(1, 0)
# Pending:
# 	X-(1, 0)
# 	Y-(1, 0)
# Sending from Fxy-(1, 0) to X-(1, 0)
# Sending from Fxy-(1, 0) to Y-(1, 0)
#
#
# Current node: Fxy-(1, 1)
# Pending:
# 	Y-(1, 1)
# 	X-(1, 1)
# Sending from Fxy-(1, 1) to Y-(1, 1)
# Sending from Fxy-(1, 1) to X-(1, 1)
#
#
# Current node: Fxy-(1, 2)
# Pending:
# 	Y-(1, 2)
# 	X-(1, 2)
# Sending from Fxy-(1, 2) to Y-(1, 2)
# Sending from Fxy-(1, 2) to X-(1, 2)
#
#
# Current node: Fxy-(1, 3)
# Pending:
# 	X-(1, 3)
# 	Y-(1, 3)
# Sending from Fxy-(1, 3) to X-(1, 3)
# Sending from Fxy-(1, 3) to Y-(1, 3)
#
#
# Current node: Fxy-(1, 4)
# Pending:
# 	Y-(1, 4)
# 	X-(1, 4)
# Sending from Fxy-(1, 4) to Y-(1, 4)
# Sending from Fxy-(1, 4) to X-(1, 4)
#
#
# Current node: Fxy-(1, 5)
# Pending:
# 	X-(1, 5)
# 	Y-(1, 5)
# Sending from Fxy-(1, 5) to X-(1, 5)
# Sending from Fxy-(1, 5) to Y-(1, 5)
#
#
# Current node: Fxy-(1, 6)
# Pending:
# 	X-(1, 6)
# 	Y-(1, 6)
# Sending from Fxy-(1, 6) to X-(1, 6)
# Sending from Fxy-(1, 6) to Y-(1, 6)
#
#
# Current node: Fxy-(1, 7)
# Pending:
# 	X-(1, 7)
# 	Y-(1, 7)
# Sending from Fxy-(1, 7) to X-(1, 7)
# Sending from Fxy-(1, 7) to Y-(1, 7)
#
#
# Current node: Fxy-(1, 8)
# Pending:
# 	Y-(1, 8)
# 	X-(1, 8)
# Sending from Fxy-(1, 8) to Y-(1, 8)
# Sending from Fxy-(1, 8) to X-(1, 8)
#
#
# Current node: Fxy-(1, 9)
# Pending:
# 	Y-(1, 9)
# 	X-(1, 9)
# Sending from Fxy-(1, 9) to Y-(1, 9)
# Sending from Fxy-(1, 9) to X-(1, 9)
#
#
# Current node: Fxy-(2, 0)
# Pending:
# 	X-(2, 0)
# 	Y-(2, 0)
# Sending from Fxy-(2, 0) to X-(2, 0)
# Sending from Fxy-(2, 0) to Y-(2, 0)
#
#
# Current node: Fxy-(2, 1)
# Pending:
# 	X-(2, 1)
# 	Y-(2, 1)
# Sending from Fxy-(2, 1) to X-(2, 1)
# Sending from Fxy-(2, 1) to Y-(2, 1)
#
#
# Current node: Fxy-(2, 2)
# Pending:
# 	Y-(2, 2)
# 	X-(2, 2)
# Sending from Fxy-(2, 2) to Y-(2, 2)
# Sending from Fxy-(2, 2) to X-(2, 2)
#
#
# Current node: Fxy-(2, 3)
# Pending:
# 	X-(2, 3)
# 	Y-(2, 3)
# Sending from Fxy-(2, 3) to X-(2, 3)
# Sending from Fxy-(2, 3) to Y-(2, 3)
#
#
# Current node: Fxy-(2, 4)
# Pending:
# 	X-(2, 4)
# 	Y-(2, 4)
# Sending from Fxy-(2, 4) to X-(2, 4)
# Sending from Fxy-(2, 4) to Y-(2, 4)
#
#
# Current node: Fxy-(2, 5)
# Pending:
# 	X-(2, 5)
# 	Y-(2, 5)
# Sending from Fxy-(2, 5) to X-(2, 5)
# Sending from Fxy-(2, 5) to Y-(2, 5)
#
#
# Current node: Fxy-(2, 6)
# Pending:
# 	X-(2, 6)
# 	Y-(2, 6)
# Sending from Fxy-(2, 6) to X-(2, 6)
# Sending from Fxy-(2, 6) to Y-(2, 6)
#
#
# Current node: Fxy-(2, 7)
# Pending:
# 	Y-(2, 7)
# 	X-(2, 7)
# Sending from Fxy-(2, 7) to Y-(2, 7)
# Sending from Fxy-(2, 7) to X-(2, 7)
#
#
# Current node: Fxy-(2, 8)
# Pending:
# 	X-(2, 8)
# 	Y-(2, 8)
# Sending from Fxy-(2, 8) to X-(2, 8)
# Sending from Fxy-(2, 8) to Y-(2, 8)
#
#
# Current node: Fxy-(2, 9)
# Pending:
# 	X-(2, 9)
# 	Y-(2, 9)
# Sending from Fxy-(2, 9) to X-(2, 9)
# Sending from Fxy-(2, 9) to Y-(2, 9)
#
#
# Current node: Fxy-(3, 0)
# Pending:
# 	Y-(3, 0)
# 	X-(3, 0)
# Sending from Fxy-(3, 0) to Y-(3, 0)
# Sending from Fxy-(3, 0) to X-(3, 0)
#
#
# Current node: Fxy-(3, 1)
# Pending:
# 	Y-(3, 1)
# 	X-(3, 1)
# Sending from Fxy-(3, 1) to Y-(3, 1)
# Sending from Fxy-(3, 1) to X-(3, 1)
#
#
# Current node: Fxy-(3, 2)
# Pending:
# 	X-(3, 2)
# 	Y-(3, 2)
# Sending from Fxy-(3, 2) to X-(3, 2)
# Sending from Fxy-(3, 2) to Y-(3, 2)
#
#
# Current node: Fxy-(3, 3)
# Pending:
# 	Y-(3, 3)
# 	X-(3, 3)
# Sending from Fxy-(3, 3) to Y-(3, 3)
# Sending from Fxy-(3, 3) to X-(3, 3)
#
#
# Current node: Fxy-(3, 4)
# Pending:
# 	X-(3, 4)
# 	Y-(3, 4)
# Sending from Fxy-(3, 4) to X-(3, 4)
# Sending from Fxy-(3, 4) to Y-(3, 4)
#
#
# Current node: Fxy-(3, 5)
# Pending:
# 	Y-(3, 5)
# 	X-(3, 5)
# Sending from Fxy-(3, 5) to Y-(3, 5)
# Sending from Fxy-(3, 5) to X-(3, 5)
#
#
# Current node: Fxy-(3, 6)
# Pending:
# 	Y-(3, 6)
# 	X-(3, 6)
# Sending from Fxy-(3, 6) to Y-(3, 6)
# Sending from Fxy-(3, 6) to X-(3, 6)
#
#
# Current node: Fxy-(3, 7)
# Pending:
# 	Y-(3, 7)
# 	X-(3, 7)
# Sending from Fxy-(3, 7) to Y-(3, 7)
# Sending from Fxy-(3, 7) to X-(3, 7)
#
#
# Current node: Fxy-(3, 8)
# Pending:
# 	X-(3, 8)
# 	Y-(3, 8)
# Sending from Fxy-(3, 8) to X-(3, 8)
# Sending from Fxy-(3, 8) to Y-(3, 8)
#
#
# Current node: Fxy-(3, 9)
# Pending:
# 	Y-(3, 9)
# 	X-(3, 9)
# Sending from Fxy-(3, 9) to Y-(3, 9)
# Sending from Fxy-(3, 9) to X-(3, 9)
#
#
# Current node: Fxy-(4, 0)
# Pending:
# 	X-(4, 0)
# 	Y-(4, 0)
# Sending from Fxy-(4, 0) to X-(4, 0)
# Sending from Fxy-(4, 0) to Y-(4, 0)
#
#
# Current node: Fxy-(4, 1)
# Pending:
# 	X-(4, 1)
# 	Y-(4, 1)
# Sending from Fxy-(4, 1) to X-(4, 1)
# Sending from Fxy-(4, 1) to Y-(4, 1)
#
#
# Current node: Fxy-(4, 2)
# Pending:
# 	X-(4, 2)
# 	Y-(4, 2)
# Sending from Fxy-(4, 2) to X-(4, 2)
# Sending from Fxy-(4, 2) to Y-(4, 2)
#
#
# Current node: Fxy-(4, 3)
# Pending:
# 	Y-(4, 3)
# 	X-(4, 3)
# Sending from Fxy-(4, 3) to Y-(4, 3)
# Sending from Fxy-(4, 3) to X-(4, 3)
#
#
# Current node: Fxy-(4, 4)
# Pending:
# 	X-(4, 4)
# 	Y-(4, 4)
# Sending from Fxy-(4, 4) to X-(4, 4)
# Sending from Fxy-(4, 4) to Y-(4, 4)
#
#
# Current node: Fxy-(4, 5)
# Pending:
# 	Y-(4, 5)
# 	X-(4, 5)
# Sending from Fxy-(4, 5) to Y-(4, 5)
# Sending from Fxy-(4, 5) to X-(4, 5)
#
#
# Current node: Fxy-(4, 6)
# Pending:
# 	X-(4, 6)
# 	Y-(4, 6)
# Sending from Fxy-(4, 6) to X-(4, 6)
# Sending from Fxy-(4, 6) to Y-(4, 6)
#
#
# Current node: Fxy-(4, 7)
# Pending:
# 	X-(4, 7)
# 	Y-(4, 7)
# Sending from Fxy-(4, 7) to X-(4, 7)
# Sending from Fxy-(4, 7) to Y-(4, 7)
#
#
# Current node: Fxy-(4, 8)
# Pending:
# 	Y-(4, 8)
# 	X-(4, 8)
# Sending from Fxy-(4, 8) to Y-(4, 8)
# Sending from Fxy-(4, 8) to X-(4, 8)
#
#
# Current node: Fxy-(4, 9)
# Pending:
# 	X-(4, 9)
# 	Y-(4, 9)
# Sending from Fxy-(4, 9) to X-(4, 9)
# Sending from Fxy-(4, 9) to Y-(4, 9)
#
#
# Current node: Fxy-(5, 0)
# Pending:
# 	X-(5, 0)
# 	Y-(5, 0)
# Sending from Fxy-(5, 0) to X-(5, 0)
# Sending from Fxy-(5, 0) to Y-(5, 0)
#
#
# Current node: Fxy-(5, 1)
# Pending:
# 	X-(5, 1)
# 	Y-(5, 1)
# Sending from Fxy-(5, 1) to X-(5, 1)
# Sending from Fxy-(5, 1) to Y-(5, 1)
#
#
# Current node: Fxy-(5, 2)
# Pending:
# 	Y-(5, 2)
# 	X-(5, 2)
# Sending from Fxy-(5, 2) to Y-(5, 2)
# Sending from Fxy-(5, 2) to X-(5, 2)
#
#
# Current node: Fxy-(5, 3)
# Pending:
# 	X-(5, 3)
# 	Y-(5, 3)
# Sending from Fxy-(5, 3) to X-(5, 3)
# Sending from Fxy-(5, 3) to Y-(5, 3)
#
#
# Current node: Fxy-(5, 4)
# Pending:
# 	Y-(5, 4)
# 	X-(5, 4)
# Sending from Fxy-(5, 4) to Y-(5, 4)
# Sending from Fxy-(5, 4) to X-(5, 4)
#
#
# Current node: Fxy-(5, 5)
# Pending:
# 	Y-(5, 5)
# 	X-(5, 5)
# Sending from Fxy-(5, 5) to Y-(5, 5)
# Sending from Fxy-(5, 5) to X-(5, 5)
#
#
# Current node: Fxy-(5, 6)
# Pending:
# 	Y-(5, 6)
# 	X-(5, 6)
# Sending from Fxy-(5, 6) to Y-(5, 6)
# Sending from Fxy-(5, 6) to X-(5, 6)
#
#
# Current node: Fxy-(5, 7)
# Pending:
# 	X-(5, 7)
# 	Y-(5, 7)
# Sending from Fxy-(5, 7) to X-(5, 7)
# Sending from Fxy-(5, 7) to Y-(5, 7)
#
#
# Current node: Fxy-(5, 8)
# Pending:
# 	X-(5, 8)
# 	Y-(5, 8)
# Sending from Fxy-(5, 8) to X-(5, 8)
# Sending from Fxy-(5, 8) to Y-(5, 8)
#
#
# Current node: Fxy-(5, 9)
# Pending:
# 	X-(5, 9)
# 	Y-(5, 9)
# Sending from Fxy-(5, 9) to X-(5, 9)
# Sending from Fxy-(5, 9) to Y-(5, 9)
#
#
# Current node: Fxy-(6, 0)
# Pending:
# 	Y-(6, 0)
# 	X-(6, 0)
# Sending from Fxy-(6, 0) to Y-(6, 0)
# Sending from Fxy-(6, 0) to X-(6, 0)
#
#
# Current node: Fxy-(6, 1)
# Pending:
# 	Y-(6, 1)
# 	X-(6, 1)
# Sending from Fxy-(6, 1) to Y-(6, 1)
# Sending from Fxy-(6, 1) to X-(6, 1)
#
#
# Current node: Fxy-(6, 2)
# Pending:
# 	Y-(6, 2)
# 	X-(6, 2)
# Sending from Fxy-(6, 2) to Y-(6, 2)
# Sending from Fxy-(6, 2) to X-(6, 2)
#
#
# Current node: Fxy-(6, 3)
# Pending:
# 	X-(6, 3)
# 	Y-(6, 3)
# Sending from Fxy-(6, 3) to X-(6, 3)
# Sending from Fxy-(6, 3) to Y-(6, 3)
#
#
# Current node: Fxy-(6, 4)
# Pending:
# 	Y-(6, 4)
# 	X-(6, 4)
# Sending from Fxy-(6, 4) to Y-(6, 4)
# Sending from Fxy-(6, 4) to X-(6, 4)
#
#
# Current node: Fxy-(6, 5)
# Pending:
# 	Y-(6, 5)
# 	X-(6, 5)
# Sending from Fxy-(6, 5) to Y-(6, 5)
# Sending from Fxy-(6, 5) to X-(6, 5)
#
#
# Current node: Fxy-(6, 6)
# Pending:
# 	Y-(6, 6)
# 	X-(6, 6)
# Sending from Fxy-(6, 6) to Y-(6, 6)
# Sending from Fxy-(6, 6) to X-(6, 6)
#
#
# Current node: Fxy-(6, 7)
# Pending:
# 	Y-(6, 7)
# 	X-(6, 7)
# Sending from Fxy-(6, 7) to Y-(6, 7)
# Sending from Fxy-(6, 7) to X-(6, 7)
#
#
# Current node: Fxy-(6, 8)
# Pending:
# 	Y-(6, 8)
# 	X-(6, 8)
# Sending from Fxy-(6, 8) to Y-(6, 8)
# Sending from Fxy-(6, 8) to X-(6, 8)
#
#
# Current node: Fxy-(6, 9)
# Pending:
# 	X-(6, 9)
# 	Y-(6, 9)
# Sending from Fxy-(6, 9) to X-(6, 9)
# Sending from Fxy-(6, 9) to Y-(6, 9)
#
#
# Current node: Fxy-(7, 0)
# Pending:
# 	Y-(7, 0)
# 	X-(7, 0)
# Sending from Fxy-(7, 0) to Y-(7, 0)
# Sending from Fxy-(7, 0) to X-(7, 0)
#
#
# Current node: Fxy-(7, 1)
# Pending:
# 	Y-(7, 1)
# 	X-(7, 1)
# Sending from Fxy-(7, 1) to Y-(7, 1)
# Sending from Fxy-(7, 1) to X-(7, 1)
#
#
# Current node: Fxy-(7, 2)
# Pending:
# 	Y-(7, 2)
# 	X-(7, 2)
# Sending from Fxy-(7, 2) to Y-(7, 2)
# Sending from Fxy-(7, 2) to X-(7, 2)
#
#
# Current node: Fxy-(7, 3)
# Pending:
# 	X-(7, 3)
# 	Y-(7, 3)
# Sending from Fxy-(7, 3) to X-(7, 3)
# Sending from Fxy-(7, 3) to Y-(7, 3)
#
#
# Current node: Fxy-(7, 4)
# Pending:
# 	Y-(7, 4)
# 	X-(7, 4)
# Sending from Fxy-(7, 4) to Y-(7, 4)
# Sending from Fxy-(7, 4) to X-(7, 4)
#
#
# Current node: Fxy-(7, 5)
# Pending:
# 	X-(7, 5)
# 	Y-(7, 5)
# Sending from Fxy-(7, 5) to X-(7, 5)
# Sending from Fxy-(7, 5) to Y-(7, 5)
#
#
# Current node: Fxy-(7, 6)
# Pending:
# 	Y-(7, 6)
# 	X-(7, 6)
# Sending from Fxy-(7, 6) to Y-(7, 6)
# Sending from Fxy-(7, 6) to X-(7, 6)
#
#
# Current node: Fxy-(7, 7)
# Pending:
# 	X-(7, 7)
# 	Y-(7, 7)
# Sending from Fxy-(7, 7) to X-(7, 7)
# Sending from Fxy-(7, 7) to Y-(7, 7)
#
#
# Current node: Fxy-(7, 8)
# Pending:
# 	Y-(7, 8)
# 	X-(7, 8)
# Sending from Fxy-(7, 8) to Y-(7, 8)
# Sending from Fxy-(7, 8) to X-(7, 8)
#
#
# Current node: Fxy-(7, 9)
# Pending:
# 	Y-(7, 9)
# 	X-(7, 9)
# Sending from Fxy-(7, 9) to Y-(7, 9)
# Sending from Fxy-(7, 9) to X-(7, 9)
#
#
# Current node: Fxy-(8, 0)
# Pending:
# 	X-(8, 0)
# 	Y-(8, 0)
# Sending from Fxy-(8, 0) to X-(8, 0)
# Sending from Fxy-(8, 0) to Y-(8, 0)
#
#
# Current node: Fxy-(8, 1)
# Pending:
# 	Y-(8, 1)
# 	X-(8, 1)
# Sending from Fxy-(8, 1) to Y-(8, 1)
# Sending from Fxy-(8, 1) to X-(8, 1)
#
#
# Current node: Fxy-(8, 2)
# Pending:
# 	X-(8, 2)
# 	Y-(8, 2)
# Sending from Fxy-(8, 2) to X-(8, 2)
# Sending from Fxy-(8, 2) to Y-(8, 2)
#
#
# Current node: Fxy-(8, 3)
# Pending:
# 	X-(8, 3)
# 	Y-(8, 3)
# Sending from Fxy-(8, 3) to X-(8, 3)
# Sending from Fxy-(8, 3) to Y-(8, 3)
#
#
# Current node: Fxy-(8, 4)
# Pending:
# 	Y-(8, 4)
# 	X-(8, 4)
# Sending from Fxy-(8, 4) to Y-(8, 4)
# Sending from Fxy-(8, 4) to X-(8, 4)
#
#
# Current node: Fxy-(8, 5)
# Pending:
# 	Y-(8, 5)
# 	X-(8, 5)
# Sending from Fxy-(8, 5) to Y-(8, 5)
# Sending from Fxy-(8, 5) to X-(8, 5)
#
#
# Current node: Fxy-(8, 6)
# Pending:
# 	Y-(8, 6)
# 	X-(8, 6)
# Sending from Fxy-(8, 6) to Y-(8, 6)
# Sending from Fxy-(8, 6) to X-(8, 6)
#
#
# Current node: Fxy-(8, 7)
# Pending:
# 	X-(8, 7)
# 	Y-(8, 7)
# Sending from Fxy-(8, 7) to X-(8, 7)
# Sending from Fxy-(8, 7) to Y-(8, 7)
#
#
# Current node: Fxy-(8, 8)
# Pending:
# 	Y-(8, 8)
# 	X-(8, 8)
# Sending from Fxy-(8, 8) to Y-(8, 8)
# Sending from Fxy-(8, 8) to X-(8, 8)
#
#
# Current node: Fxy-(8, 9)
# Pending:
# 	Y-(8, 9)
# 	X-(8, 9)
# Sending from Fxy-(8, 9) to Y-(8, 9)
# Sending from Fxy-(8, 9) to X-(8, 9)
#
#
# Current node: Fxy-(9, 0)
# Pending:
# 	Y-(9, 0)
# 	X-(9, 0)
# Sending from Fxy-(9, 0) to Y-(9, 0)
# Sending from Fxy-(9, 0) to X-(9, 0)
#
#
# Current node: Fxy-(9, 1)
# Pending:
# 	X-(9, 1)
# 	Y-(9, 1)
# Sending from Fxy-(9, 1) to X-(9, 1)
# Sending from Fxy-(9, 1) to Y-(9, 1)
#
#
# Current node: Fxy-(9, 2)
# Pending:
# 	X-(9, 2)
# 	Y-(9, 2)
# Sending from Fxy-(9, 2) to X-(9, 2)
# Sending from Fxy-(9, 2) to Y-(9, 2)
#
#
# Current node: Fxy-(9, 3)
# Pending:
# 	X-(9, 3)
# 	Y-(9, 3)
# Sending from Fxy-(9, 3) to X-(9, 3)
# Sending from Fxy-(9, 3) to Y-(9, 3)
#
#
# Current node: Fxy-(9, 4)
# Pending:
# 	X-(9, 4)
# 	Y-(9, 4)
# Sending from Fxy-(9, 4) to X-(9, 4)
# Sending from Fxy-(9, 4) to Y-(9, 4)
#
#
# Current node: Fxy-(9, 5)
# Pending:
# 	X-(9, 5)
# 	Y-(9, 5)
# Sending from Fxy-(9, 5) to X-(9, 5)
# Sending from Fxy-(9, 5) to Y-(9, 5)
#
#
# Current node: Fxy-(9, 6)
# Pending:
# 	X-(9, 6)
# 	Y-(9, 6)
# Sending from Fxy-(9, 6) to X-(9, 6)
# Sending from Fxy-(9, 6) to Y-(9, 6)
#
#
# Current node: Fxy-(9, 7)
# Pending:
# 	X-(9, 7)
# 	Y-(9, 7)
# Sending from Fxy-(9, 7) to X-(9, 7)
# Sending from Fxy-(9, 7) to Y-(9, 7)
#
#
# Current node: Fxy-(9, 8)
# Pending:
# 	X-(9, 8)
# 	Y-(9, 8)
# Sending from Fxy-(9, 8) to X-(9, 8)
# Sending from Fxy-(9, 8) to Y-(9, 8)
#
#
# Current node: Fxy-(9, 9)
# Pending:
# 	X-(9, 9)
# 	Y-(9, 9)
# Sending from Fxy-(9, 9) to X-(9, 9)
# Sending from Fxy-(9, 9) to Y-(9, 9)
#
#
# Current node: X-(0, 0)
# Pending:
# 	Fxx-(0-1,0)
# 	Fxy-(0, 0)
# 	Fxx-(0,0-1)
# Sending from X-(0, 0) to Fxx-(0-1,0)
# Sending from X-(0, 0) to Fxy-(0, 0)
# Sending from X-(0, 0) to Fxx-(0,0-1)
#
#
# Current node: X-(0, 1)
# Pending:
# 	Fxx-(0-1,1)
# 	Fxy-(0, 1)
# 	Fxx-(0,0-1)
# 	Fxx-(0,1-2)
# Sending from X-(0, 1) to Fxx-(0-1,1)
# Sending from X-(0, 1) to Fxy-(0, 1)
# Sending from X-(0, 1) to Fxx-(0,0-1)
# Sending from X-(0, 1) to Fxx-(0,1-2)
#
#
# Current node: X-(0, 2)
# Pending:
# 	Fxx-(0-1,2)
# 	Fxy-(0, 2)
# 	Fxx-(0,2-3)
# 	Fxx-(0,1-2)
# Sending from X-(0, 2) to Fxx-(0-1,2)
# Sending from X-(0, 2) to Fxy-(0, 2)
# Sending from X-(0, 2) to Fxx-(0,2-3)
# Sending from X-(0, 2) to Fxx-(0,1-2)
#
#
# Current node: X-(0, 3)
# Pending:
# 	Fxy-(0, 3)
# 	Fxx-(0,2-3)
# 	Fxx-(0,3-4)
# 	Fxx-(0-1,3)
# Sending from X-(0, 3) to Fxy-(0, 3)
# Sending from X-(0, 3) to Fxx-(0,2-3)
# Sending from X-(0, 3) to Fxx-(0,3-4)
# Sending from X-(0, 3) to Fxx-(0-1,3)
#
#
# Current node: X-(0, 4)
# Pending:
# 	Fxx-(0,3-4)
# 	Fxx-(0-1,4)
# 	Fxy-(0, 4)
# 	Fxx-(0,4-5)
# Sending from X-(0, 4) to Fxx-(0,3-4)
# Sending from X-(0, 4) to Fxx-(0-1,4)
# Sending from X-(0, 4) to Fxy-(0, 4)
# Sending from X-(0, 4) to Fxx-(0,4-5)
#
#
# Current node: X-(0, 5)
# Pending:
# 	Fxy-(0, 5)
# 	Fxx-(0-1,5)
# 	Fxx-(0,5-6)
# 	Fxx-(0,4-5)
# Sending from X-(0, 5) to Fxy-(0, 5)
# Sending from X-(0, 5) to Fxx-(0-1,5)
# Sending from X-(0, 5) to Fxx-(0,5-6)
# Sending from X-(0, 5) to Fxx-(0,4-5)
#
#
# Current node: X-(0, 6)
# Pending:
# 	Fxx-(0,6-7)
# 	Fxy-(0, 6)
# 	Fxx-(0,5-6)
# 	Fxx-(0-1,6)
# Sending from X-(0, 6) to Fxx-(0,6-7)
# Sending from X-(0, 6) to Fxy-(0, 6)
# Sending from X-(0, 6) to Fxx-(0,5-6)
# Sending from X-(0, 6) to Fxx-(0-1,6)
#
#
# Current node: X-(0, 7)
# Pending:
# 	Fxx-(0-1,7)
# 	Fxx-(0,6-7)
# 	Fxx-(0,7-8)
# 	Fxy-(0, 7)
# Sending from X-(0, 7) to Fxx-(0-1,7)
# Sending from X-(0, 7) to Fxx-(0,6-7)
# Sending from X-(0, 7) to Fxx-(0,7-8)
# Sending from X-(0, 7) to Fxy-(0, 7)
#
#
# Current node: X-(0, 8)
# Pending:
# 	Fxx-(0-1,8)
# 	Fxx-(0,8-9)
# 	Fxy-(0, 8)
# 	Fxx-(0,7-8)
# Sending from X-(0, 8) to Fxx-(0-1,8)
# Sending from X-(0, 8) to Fxx-(0,8-9)
# Sending from X-(0, 8) to Fxy-(0, 8)
# Sending from X-(0, 8) to Fxx-(0,7-8)
#
#
# Current node: X-(0, 9)
# Pending:
# 	Fxx-(0-1,9)
# 	Fxx-(0,8-9)
# 	Fxy-(0, 9)
# Sending from X-(0, 9) to Fxx-(0-1,9)
# Sending from X-(0, 9) to Fxx-(0,8-9)
# Sending from X-(0, 9) to Fxy-(0, 9)
#
#
# Current node: X-(1, 0)
# Pending:
# 	Fxx-(1,0-1)
# 	Fxy-(1, 0)
# 	Fxx-(1-2,0)
# 	Fxx-(0-1,0)
# Sending from X-(1, 0) to Fxx-(1,0-1)
# Sending from X-(1, 0) to Fxy-(1, 0)
# Sending from X-(1, 0) to Fxx-(1-2,0)
# Sending from X-(1, 0) to Fxx-(0-1,0)
#
#
# Current node: X-(1, 1)
# Pending:
# 	Fxy-(1, 1)
# 	Fxx-(0-1,1)
# 	Fxx-(1-2,1)
# 	Fxx-(1,0-1)
# 	Fxx-(1,1-2)
# Sending from X-(1, 1) to Fxy-(1, 1)
# Sending from X-(1, 1) to Fxx-(0-1,1)
# Sending from X-(1, 1) to Fxx-(1-2,1)
# Sending from X-(1, 1) to Fxx-(1,0-1)
# Sending from X-(1, 1) to Fxx-(1,1-2)
#
#
# Current node: X-(1, 2)
# Pending:
# 	Fxx-(1,2-3)
# 	Fxy-(1, 2)
# 	Fxx-(0-1,2)
# 	Fxx-(1-2,2)
# 	Fxx-(1,1-2)
# Sending from X-(1, 2) to Fxx-(1,2-3)
# Sending from X-(1, 2) to Fxy-(1, 2)
# Sending from X-(1, 2) to Fxx-(0-1,2)
# Sending from X-(1, 2) to Fxx-(1-2,2)
# Sending from X-(1, 2) to Fxx-(1,1-2)
#
#
# Current node: X-(1, 3)
# Pending:
# 	Fxx-(1,2-3)
# 	Fxy-(1, 3)
# 	Fxx-(0-1,3)
# 	Fxx-(1-2,3)
# 	Fxx-(1,3-4)
# Sending from X-(1, 3) to Fxx-(1,2-3)
# Sending from X-(1, 3) to Fxy-(1, 3)
# Sending from X-(1, 3) to Fxx-(0-1,3)
# Sending from X-(1, 3) to Fxx-(1-2,3)
# Sending from X-(1, 3) to Fxx-(1,3-4)
#
#
# Current node: X-(1, 4)
# Pending:
# 	Fxx-(0-1,4)
# 	Fxx-(1-2,4)
# 	Fxx-(1,3-4)
# 	Fxx-(1,4-5)
# 	Fxy-(1, 4)
# Sending from X-(1, 4) to Fxx-(0-1,4)
# Sending from X-(1, 4) to Fxx-(1-2,4)
# Sending from X-(1, 4) to Fxx-(1,3-4)
# Sending from X-(1, 4) to Fxx-(1,4-5)
# Sending from X-(1, 4) to Fxy-(1, 4)
#
#
# Current node: X-(1, 5)
# Pending:
# 	Fxx-(0-1,5)
# 	Fxx-(1-2,5)
# 	Fxy-(1, 5)
# 	Fxx-(1,4-5)
# 	Fxx-(1,5-6)
# Sending from X-(1, 5) to Fxx-(0-1,5)
# Sending from X-(1, 5) to Fxx-(1-2,5)
# Sending from X-(1, 5) to Fxy-(1, 5)
# Sending from X-(1, 5) to Fxx-(1,4-5)
# Sending from X-(1, 5) to Fxx-(1,5-6)
#
#
# Current node: X-(1, 6)
# Pending:
# 	Fxx-(1,6-7)
# 	Fxx-(0-1,6)
# 	Fxx-(1-2,6)
# 	Fxy-(1, 6)
# 	Fxx-(1,5-6)
# Sending from X-(1, 6) to Fxx-(1,6-7)
# Sending from X-(1, 6) to Fxx-(0-1,6)
# Sending from X-(1, 6) to Fxx-(1-2,6)
# Sending from X-(1, 6) to Fxy-(1, 6)
# Sending from X-(1, 6) to Fxx-(1,5-6)
#
#
# Current node: X-(1, 7)
# Pending:
# 	Fxx-(1,7-8)
# 	Fxx-(1,6-7)
# 	Fxx-(0-1,7)
# 	Fxx-(1-2,7)
# 	Fxy-(1, 7)
# Sending from X-(1, 7) to Fxx-(1,7-8)
# Sending from X-(1, 7) to Fxx-(1,6-7)
# Sending from X-(1, 7) to Fxx-(0-1,7)
# Sending from X-(1, 7) to Fxx-(1-2,7)
# Sending from X-(1, 7) to Fxy-(1, 7)
#
#
# Current node: X-(1, 8)
# Pending:
# 	Fxx-(1,7-8)
# 	Fxy-(1, 8)
# 	Fxx-(1,8-9)
# 	Fxx-(0-1,8)
# 	Fxx-(1-2,8)
# Sending from X-(1, 8) to Fxx-(1,7-8)
# Sending from X-(1, 8) to Fxy-(1, 8)
# Sending from X-(1, 8) to Fxx-(1,8-9)
# Sending from X-(1, 8) to Fxx-(0-1,8)
# Sending from X-(1, 8) to Fxx-(1-2,8)
#
#
# Current node: X-(1, 9)
# Pending:
# 	Fxx-(0-1,9)
# 	Fxx-(1-2,9)
# 	Fxy-(1, 9)
# 	Fxx-(1,8-9)
# Sending from X-(1, 9) to Fxx-(0-1,9)
# Sending from X-(1, 9) to Fxx-(1-2,9)
# Sending from X-(1, 9) to Fxy-(1, 9)
# Sending from X-(1, 9) to Fxx-(1,8-9)
#
#
# Current node: X-(2, 0)
# Pending:
# 	Fxx-(2-3,0)
# 	Fxy-(2, 0)
# 	Fxx-(2,0-1)
# 	Fxx-(1-2,0)
# Sending from X-(2, 0) to Fxx-(2-3,0)
# Sending from X-(2, 0) to Fxy-(2, 0)
# Sending from X-(2, 0) to Fxx-(2,0-1)
# Sending from X-(2, 0) to Fxx-(1-2,0)
#
#
# Current node: X-(2, 1)
# Pending:
# 	Fxx-(1-2,1)
# 	Fxx-(2-3,1)
# 	Fxy-(2, 1)
# 	Fxx-(2,1-2)
# 	Fxx-(2,0-1)
# Sending from X-(2, 1) to Fxx-(1-2,1)
# Sending from X-(2, 1) to Fxx-(2-3,1)
# Sending from X-(2, 1) to Fxy-(2, 1)
# Sending from X-(2, 1) to Fxx-(2,1-2)
# Sending from X-(2, 1) to Fxx-(2,0-1)
#
#
# Current node: X-(2, 2)
# Pending:
# 	Fxx-(1-2,2)
# 	Fxx-(2,2-3)
# 	Fxx-(2-3,2)
# 	Fxy-(2, 2)
# 	Fxx-(2,1-2)
# Sending from X-(2, 2) to Fxx-(1-2,2)
# Sending from X-(2, 2) to Fxx-(2,2-3)
# Sending from X-(2, 2) to Fxx-(2-3,2)
# Sending from X-(2, 2) to Fxy-(2, 2)
# Sending from X-(2, 2) to Fxx-(2,1-2)
#
#
# Current node: X-(2, 3)
# Pending:
# 	Fxy-(2, 3)
# 	Fxx-(1-2,3)
# 	Fxx-(2,2-3)
# 	Fxx-(2-3,3)
# 	Fxx-(2,3-4)
# Sending from X-(2, 3) to Fxy-(2, 3)
# Sending from X-(2, 3) to Fxx-(1-2,3)
# Sending from X-(2, 3) to Fxx-(2,2-3)
# Sending from X-(2, 3) to Fxx-(2-3,3)
# Sending from X-(2, 3) to Fxx-(2,3-4)
#
#
# Current node: X-(2, 4)
# Pending:
# 	Fxx-(1-2,4)
# 	Fxy-(2, 4)
# 	Fxx-(2,3-4)
# 	Fxx-(2,4-5)
# 	Fxx-(2-3,4)
# Sending from X-(2, 4) to Fxx-(1-2,4)
# Sending from X-(2, 4) to Fxy-(2, 4)
# Sending from X-(2, 4) to Fxx-(2,3-4)
# Sending from X-(2, 4) to Fxx-(2,4-5)
# Sending from X-(2, 4) to Fxx-(2-3,4)
#
#
# Current node: X-(2, 5)
# Pending:
# 	Fxy-(2, 5)
# 	Fxx-(1-2,5)
# 	Fxx-(2-3,5)
# 	Fxx-(2,4-5)
# 	Fxx-(2,5-6)
# Sending from X-(2, 5) to Fxy-(2, 5)
# Sending from X-(2, 5) to Fxx-(1-2,5)
# Sending from X-(2, 5) to Fxx-(2-3,5)
# Sending from X-(2, 5) to Fxx-(2,4-5)
# Sending from X-(2, 5) to Fxx-(2,5-6)
#
#
# Current node: X-(2, 6)
# Pending:
# 	Fxy-(2, 6)
# 	Fxx-(1-2,6)
# 	Fxx-(2-3,6)
# 	Fxx-(2,6-7)
# 	Fxx-(2,5-6)
# Sending from X-(2, 6) to Fxy-(2, 6)
# Sending from X-(2, 6) to Fxx-(1-2,6)
# Sending from X-(2, 6) to Fxx-(2-3,6)
# Sending from X-(2, 6) to Fxx-(2,6-7)
# Sending from X-(2, 6) to Fxx-(2,5-6)
#
#
# Current node: X-(2, 7)
# Pending:
# 	Fxx-(1-2,7)
# 	Fxx-(2,7-8)
# 	Fxy-(2, 7)
# 	Fxx-(2-3,7)
# 	Fxx-(2,6-7)
# Sending from X-(2, 7) to Fxx-(1-2,7)
# Sending from X-(2, 7) to Fxx-(2,7-8)
# Sending from X-(2, 7) to Fxy-(2, 7)
# Sending from X-(2, 7) to Fxx-(2-3,7)
# Sending from X-(2, 7) to Fxx-(2,6-7)
#
#
# Current node: X-(2, 8)
# Pending:
# 	Fxx-(2,8-9)
# 	Fxx-(1-2,8)
# 	Fxx-(2,7-8)
# 	Fxy-(2, 8)
# 	Fxx-(2-3,8)
# Sending from X-(2, 8) to Fxx-(2,8-9)
# Sending from X-(2, 8) to Fxx-(1-2,8)
# Sending from X-(2, 8) to Fxx-(2,7-8)
# Sending from X-(2, 8) to Fxy-(2, 8)
# Sending from X-(2, 8) to Fxx-(2-3,8)
#
#
# Current node: X-(2, 9)
# Pending:
# 	Fxx-(2-3,9)
# 	Fxy-(2, 9)
# 	Fxx-(2,8-9)
# 	Fxx-(1-2,9)
# Sending from X-(2, 9) to Fxx-(2-3,9)
# Sending from X-(2, 9) to Fxy-(2, 9)
# Sending from X-(2, 9) to Fxx-(2,8-9)
# Sending from X-(2, 9) to Fxx-(1-2,9)
#
#
# Current node: X-(3, 0)
# Pending:
# 	Fxx-(2-3,0)
# 	Fxy-(3, 0)
# 	Fxx-(3,0-1)
# 	Fxx-(3-4,0)
# Sending from X-(3, 0) to Fxx-(2-3,0)
# Sending from X-(3, 0) to Fxy-(3, 0)
# Sending from X-(3, 0) to Fxx-(3,0-1)
# Sending from X-(3, 0) to Fxx-(3-4,0)
#
#
# Current node: X-(3, 1)
# Pending:
# 	Fxy-(3, 1)
# 	Fxx-(3,0-1)
# 	Fxx-(3,1-2)
# 	Fxx-(2-3,1)
# 	Fxx-(3-4,1)
# Sending from X-(3, 1) to Fxy-(3, 1)
# Sending from X-(3, 1) to Fxx-(3,0-1)
# Sending from X-(3, 1) to Fxx-(3,1-2)
# Sending from X-(3, 1) to Fxx-(2-3,1)
# Sending from X-(3, 1) to Fxx-(3-4,1)
#
#
# Current node: X-(3, 2)
# Pending:
# 	Fxy-(3, 2)
# 	Fxx-(2-3,2)
# 	Fxx-(3,1-2)
# 	Fxx-(3-4,2)
# 	Fxx-(3,2-3)
# Sending from X-(3, 2) to Fxy-(3, 2)
# Sending from X-(3, 2) to Fxx-(2-3,2)
# Sending from X-(3, 2) to Fxx-(3,1-2)
# Sending from X-(3, 2) to Fxx-(3-4,2)
# Sending from X-(3, 2) to Fxx-(3,2-3)
#
#
# Current node: X-(3, 3)
# Pending:
# 	Fxy-(3, 3)
# 	Fxx-(3,3-4)
# 	Fxx-(2-3,3)
# 	Fxx-(3-4,3)
# 	Fxx-(3,2-3)
# Sending from X-(3, 3) to Fxy-(3, 3)
# Sending from X-(3, 3) to Fxx-(3,3-4)
# Sending from X-(3, 3) to Fxx-(2-3,3)
# Sending from X-(3, 3) to Fxx-(3-4,3)
# Sending from X-(3, 3) to Fxx-(3,2-3)
#
#
# Current node: X-(3, 4)
# Pending:
# 	Fxx-(3,3-4)
# 	Fxx-(3,4-5)
# 	Fxx-(2-3,4)
# 	Fxy-(3, 4)
# 	Fxx-(3-4,4)
# Sending from X-(3, 4) to Fxx-(3,3-4)
# Sending from X-(3, 4) to Fxx-(3,4-5)
# Sending from X-(3, 4) to Fxx-(2-3,4)
# Sending from X-(3, 4) to Fxy-(3, 4)
# Sending from X-(3, 4) to Fxx-(3-4,4)
#
#
# Current node: X-(3, 5)
# Pending:
# 	Fxy-(3, 5)
# 	Fxx-(3,4-5)
# 	Fxx-(2-3,5)
# 	Fxx-(3-4,5)
# 	Fxx-(3,5-6)
# Sending from X-(3, 5) to Fxy-(3, 5)
# Sending from X-(3, 5) to Fxx-(3,4-5)
# Sending from X-(3, 5) to Fxx-(2-3,5)
# Sending from X-(3, 5) to Fxx-(3-4,5)
# Sending from X-(3, 5) to Fxx-(3,5-6)
#
#
# Current node: X-(3, 6)
# Pending:
# 	Fxy-(3, 6)
# 	Fxx-(3,6-7)
# 	Fxx-(2-3,6)
# 	Fxx-(3-4,6)
# 	Fxx-(3,5-6)
# Sending from X-(3, 6) to Fxy-(3, 6)
# Sending from X-(3, 6) to Fxx-(3,6-7)
# Sending from X-(3, 6) to Fxx-(2-3,6)
# Sending from X-(3, 6) to Fxx-(3-4,6)
# Sending from X-(3, 6) to Fxx-(3,5-6)
#
#
# Current node: X-(3, 7)
# Pending:
# 	Fxy-(3, 7)
# 	Fxx-(3,6-7)
# 	Fxx-(2-3,7)
# 	Fxx-(3,7-8)
# 	Fxx-(3-4,7)
# Sending from X-(3, 7) to Fxy-(3, 7)
# Sending from X-(3, 7) to Fxx-(3,6-7)
# Sending from X-(3, 7) to Fxx-(2-3,7)
# Sending from X-(3, 7) to Fxx-(3,7-8)
# Sending from X-(3, 7) to Fxx-(3-4,7)
#
#
# Current node: X-(3, 8)
# Pending:
# 	Fxy-(3, 8)
# 	Fxx-(2-3,8)
# 	Fxx-(3,7-8)
# 	Fxx-(3-4,8)
# 	Fxx-(3,8-9)
# Sending from X-(3, 8) to Fxy-(3, 8)
# Sending from X-(3, 8) to Fxx-(2-3,8)
# Sending from X-(3, 8) to Fxx-(3,7-8)
# Sending from X-(3, 8) to Fxx-(3-4,8)
# Sending from X-(3, 8) to Fxx-(3,8-9)
#
#
# Current node: X-(3, 9)
# Pending:
# 	Fxx-(2-3,9)
# 	Fxy-(3, 9)
# 	Fxx-(3-4,9)
# 	Fxx-(3,8-9)
# Sending from X-(3, 9) to Fxx-(2-3,9)
# Sending from X-(3, 9) to Fxy-(3, 9)
# Sending from X-(3, 9) to Fxx-(3-4,9)
# Sending from X-(3, 9) to Fxx-(3,8-9)
#
#
# Current node: X-(4, 0)
# Pending:
# 	Fxy-(4, 0)
# 	Fxx-(4,0-1)
# 	Fxx-(3-4,0)
# 	Fxx-(4-5,0)
# Sending from X-(4, 0) to Fxy-(4, 0)
# Sending from X-(4, 0) to Fxx-(4,0-1)
# Sending from X-(4, 0) to Fxx-(3-4,0)
# Sending from X-(4, 0) to Fxx-(4-5,0)
#
#
# Current node: X-(4, 1)
# Pending:
# 	Fxx-(4,0-1)
# 	Fxx-(3-4,1)
# 	Fxx-(4,1-2)
# 	Fxx-(4-5,1)
# 	Fxy-(4, 1)
# Sending from X-(4, 1) to Fxx-(4,0-1)
# Sending from X-(4, 1) to Fxx-(3-4,1)
# Sending from X-(4, 1) to Fxx-(4,1-2)
# Sending from X-(4, 1) to Fxx-(4-5,1)
# Sending from X-(4, 1) to Fxy-(4, 1)
#
#
# Current node: X-(4, 2)
# Pending:
# 	Fxx-(3-4,2)
# 	Fxx-(4,1-2)
# 	Fxx-(4-5,2)
# 	Fxy-(4, 2)
# 	Fxx-(4,2-3)
# Sending from X-(4, 2) to Fxx-(3-4,2)
# Sending from X-(4, 2) to Fxx-(4,1-2)
# Sending from X-(4, 2) to Fxx-(4-5,2)
# Sending from X-(4, 2) to Fxy-(4, 2)
# Sending from X-(4, 2) to Fxx-(4,2-3)
#
#
# Current node: X-(4, 3)
# Pending:
# 	Fxx-(4,3-4)
# 	Fxx-(3-4,3)
# 	Fxy-(4, 3)
# 	Fxx-(4-5,3)
# 	Fxx-(4,2-3)
# Sending from X-(4, 3) to Fxx-(4,3-4)
# Sending from X-(4, 3) to Fxx-(3-4,3)
# Sending from X-(4, 3) to Fxy-(4, 3)
# Sending from X-(4, 3) to Fxx-(4-5,3)
# Sending from X-(4, 3) to Fxx-(4,2-3)
#
#
# Current node: X-(4, 4)
# Pending:
# 	Fxx-(4,3-4)
# 	Fxy-(4, 4)
# 	Fxx-(3-4,4)
# 	Fxx-(4-5,4)
# 	Fxx-(4,4-5)
# Sending from X-(4, 4) to Fxx-(4,3-4)
# Sending from X-(4, 4) to Fxy-(4, 4)
# Sending from X-(4, 4) to Fxx-(3-4,4)
# Sending from X-(4, 4) to Fxx-(4-5,4)
# Sending from X-(4, 4) to Fxx-(4,4-5)
#
#
# Current node: X-(4, 5)
# Pending:
# 	Fxy-(4, 5)
# 	Fxx-(4,5-6)
# 	Fxx-(3-4,5)
# 	Fxx-(4-5,5)
# 	Fxx-(4,4-5)
# Sending from X-(4, 5) to Fxy-(4, 5)
# Sending from X-(4, 5) to Fxx-(4,5-6)
# Sending from X-(4, 5) to Fxx-(3-4,5)
# Sending from X-(4, 5) to Fxx-(4-5,5)
# Sending from X-(4, 5) to Fxx-(4,4-5)
#
#
# Current node: X-(4, 6)
# Pending:
# 	Fxx-(4,5-6)
# 	Fxx-(4,6-7)
# 	Fxy-(4, 6)
# 	Fxx-(3-4,6)
# 	Fxx-(4-5,6)
# Sending from X-(4, 6) to Fxx-(4,5-6)
# Sending from X-(4, 6) to Fxx-(4,6-7)
# Sending from X-(4, 6) to Fxy-(4, 6)
# Sending from X-(4, 6) to Fxx-(3-4,6)
# Sending from X-(4, 6) to Fxx-(4-5,6)
#
#
# Current node: X-(4, 7)
# Pending:
# 	Fxx-(4,7-8)
# 	Fxx-(4,6-7)
# 	Fxy-(4, 7)
# 	Fxx-(3-4,7)
# 	Fxx-(4-5,7)
# Sending from X-(4, 7) to Fxx-(4,7-8)
# Sending from X-(4, 7) to Fxx-(4,6-7)
# Sending from X-(4, 7) to Fxy-(4, 7)
# Sending from X-(4, 7) to Fxx-(3-4,7)
# Sending from X-(4, 7) to Fxx-(4-5,7)
#
#
# Current node: X-(4, 8)
# Pending:
# 	Fxx-(4,7-8)
# 	Fxx-(4,8-9)
# 	Fxx-(3-4,8)
# 	Fxx-(4-5,8)
# 	Fxy-(4, 8)
# Sending from X-(4, 8) to Fxx-(4,7-8)
# Sending from X-(4, 8) to Fxx-(4,8-9)
# Sending from X-(4, 8) to Fxx-(3-4,8)
# Sending from X-(4, 8) to Fxx-(4-5,8)
# Sending from X-(4, 8) to Fxy-(4, 8)
#
#
# Current node: X-(4, 9)
# Pending:
# 	Fxx-(3-4,9)
# 	Fxy-(4, 9)
# 	Fxx-(4,8-9)
# 	Fxx-(4-5,9)
# Sending from X-(4, 9) to Fxx-(3-4,9)
# Sending from X-(4, 9) to Fxy-(4, 9)
# Sending from X-(4, 9) to Fxx-(4,8-9)
# Sending from X-(4, 9) to Fxx-(4-5,9)
#
#
# Current node: X-(5, 0)
# Pending:
# 	Fxy-(5, 0)
# 	Fxx-(5-6,0)
# 	Fxx-(4-5,0)
# 	Fxx-(5,0-1)
# Sending from X-(5, 0) to Fxy-(5, 0)
# Sending from X-(5, 0) to Fxx-(5-6,0)
# Sending from X-(5, 0) to Fxx-(4-5,0)
# Sending from X-(5, 0) to Fxx-(5,0-1)
#
#
# Current node: X-(5, 1)
# Pending:
# 	Fxx-(5,0-1)
# 	Fxy-(5, 1)
# 	Fxx-(5,1-2)
# 	Fxx-(4-5,1)
# 	Fxx-(5-6,1)
# Sending from X-(5, 1) to Fxx-(5,0-1)
# Sending from X-(5, 1) to Fxy-(5, 1)
# Sending from X-(5, 1) to Fxx-(5,1-2)
# Sending from X-(5, 1) to Fxx-(4-5,1)
# Sending from X-(5, 1) to Fxx-(5-6,1)
#
#
# Current node: X-(5, 2)
# Pending:
# 	Fxy-(5, 2)
# 	Fxx-(5-6,2)
# 	Fxx-(5,1-2)
# 	Fxx-(4-5,2)
# 	Fxx-(5,2-3)
# Sending from X-(5, 2) to Fxy-(5, 2)
# Sending from X-(5, 2) to Fxx-(5-6,2)
# Sending from X-(5, 2) to Fxx-(5,1-2)
# Sending from X-(5, 2) to Fxx-(4-5,2)
# Sending from X-(5, 2) to Fxx-(5,2-3)
#
#
# Current node: X-(5, 3)
# Pending:
# 	Fxy-(5, 3)
# 	Fxx-(5,3-4)
# 	Fxx-(4-5,3)
# 	Fxx-(5-6,3)
# 	Fxx-(5,2-3)
# Sending from X-(5, 3) to Fxy-(5, 3)
# Sending from X-(5, 3) to Fxx-(5,3-4)
# Sending from X-(5, 3) to Fxx-(4-5,3)
# Sending from X-(5, 3) to Fxx-(5-6,3)
# Sending from X-(5, 3) to Fxx-(5,2-3)
#
#
# Current node: X-(5, 4)
# Pending:
# 	Fxy-(5, 4)
# 	Fxx-(5,3-4)
# 	Fxx-(5,4-5)
# 	Fxx-(4-5,4)
# 	Fxx-(5-6,4)
# Sending from X-(5, 4) to Fxy-(5, 4)
# Sending from X-(5, 4) to Fxx-(5,3-4)
# Sending from X-(5, 4) to Fxx-(5,4-5)
# Sending from X-(5, 4) to Fxx-(4-5,4)
# Sending from X-(5, 4) to Fxx-(5-6,4)
#
#
# Current node: X-(5, 5)
# Pending:
# 	Fxy-(5, 5)
# 	Fxx-(5,5-6)
# 	Fxx-(5,4-5)
# 	Fxx-(4-5,5)
# 	Fxx-(5-6,5)
# Sending from X-(5, 5) to Fxy-(5, 5)
# Sending from X-(5, 5) to Fxx-(5,5-6)
# Sending from X-(5, 5) to Fxx-(5,4-5)
# Sending from X-(5, 5) to Fxx-(4-5,5)
# Sending from X-(5, 5) to Fxx-(5-6,5)
#
#
# Current node: X-(5, 6)
# Pending:
# 	Fxx-(5,6-7)
# 	Fxx-(5,5-6)
# 	Fxx-(5-6,6)
# 	Fxx-(4-5,6)
# 	Fxy-(5, 6)
# Sending from X-(5, 6) to Fxx-(5,6-7)
# Sending from X-(5, 6) to Fxx-(5,5-6)
# Sending from X-(5, 6) to Fxx-(5-6,6)
# Sending from X-(5, 6) to Fxx-(4-5,6)
# Sending from X-(5, 6) to Fxy-(5, 6)
#
#
# Current node: X-(5, 7)
# Pending:
# 	Fxx-(5,6-7)
# 	Fxx-(5,7-8)
# 	Fxy-(5, 7)
# 	Fxx-(4-5,7)
# 	Fxx-(5-6,7)
# Sending from X-(5, 7) to Fxx-(5,6-7)
# Sending from X-(5, 7) to Fxx-(5,7-8)
# Sending from X-(5, 7) to Fxy-(5, 7)
# Sending from X-(5, 7) to Fxx-(4-5,7)
# Sending from X-(5, 7) to Fxx-(5-6,7)
#
#
# Current node: X-(5, 8)
# Pending:
# 	Fxy-(5, 8)
# 	Fxx-(5,7-8)
# 	Fxx-(5,8-9)
# 	Fxx-(4-5,8)
# 	Fxx-(5-6,8)
# Sending from X-(5, 8) to Fxy-(5, 8)
# Sending from X-(5, 8) to Fxx-(5,7-8)
# Sending from X-(5, 8) to Fxx-(5,8-9)
# Sending from X-(5, 8) to Fxx-(4-5,8)
# Sending from X-(5, 8) to Fxx-(5-6,8)
#
#
# Current node: X-(5, 9)
# Pending:
# 	Fxx-(4-5,9)
# 	Fxx-(5-6,9)
# 	Fxx-(5,8-9)
# 	Fxy-(5, 9)
# Sending from X-(5, 9) to Fxx-(4-5,9)
# Sending from X-(5, 9) to Fxx-(5-6,9)
# Sending from X-(5, 9) to Fxx-(5,8-9)
# Sending from X-(5, 9) to Fxy-(5, 9)
#
#
# Current node: X-(6, 0)
# Pending:
# 	Fxx-(6,0-1)
# 	Fxx-(5-6,0)
# 	Fxy-(6, 0)
# 	Fxx-(6-7,0)
# Sending from X-(6, 0) to Fxx-(6,0-1)
# Sending from X-(6, 0) to Fxx-(5-6,0)
# Sending from X-(6, 0) to Fxy-(6, 0)
# Sending from X-(6, 0) to Fxx-(6-7,0)
#
#
# Current node: X-(6, 1)
# Pending:
# 	Fxy-(6, 1)
# 	Fxx-(6,0-1)
# 	Fxx-(6,1-2)
# 	Fxx-(5-6,1)
# 	Fxx-(6-7,1)
# Sending from X-(6, 1) to Fxy-(6, 1)
# Sending from X-(6, 1) to Fxx-(6,0-1)
# Sending from X-(6, 1) to Fxx-(6,1-2)
# Sending from X-(6, 1) to Fxx-(5-6,1)
# Sending from X-(6, 1) to Fxx-(6-7,1)
#
#
# Current node: X-(6, 2)
# Pending:
# 	Fxx-(6,2-3)
# 	Fxy-(6, 2)
# 	Fxx-(6,1-2)
# 	Fxx-(5-6,2)
# 	Fxx-(6-7,2)
# Sending from X-(6, 2) to Fxx-(6,2-3)
# Sending from X-(6, 2) to Fxy-(6, 2)
# Sending from X-(6, 2) to Fxx-(6,1-2)
# Sending from X-(6, 2) to Fxx-(5-6,2)
# Sending from X-(6, 2) to Fxx-(6-7,2)
#
#
# Current node: X-(6, 3)
# Pending:
# 	Fxy-(6, 3)
# 	Fxx-(6,2-3)
# 	Fxx-(6,3-4)
# 	Fxx-(5-6,3)
# 	Fxx-(6-7,3)
# Sending from X-(6, 3) to Fxy-(6, 3)
# Sending from X-(6, 3) to Fxx-(6,2-3)
# Sending from X-(6, 3) to Fxx-(6,3-4)
# Sending from X-(6, 3) to Fxx-(5-6,3)
# Sending from X-(6, 3) to Fxx-(6-7,3)
#
#
# Current node: X-(6, 4)
# Pending:
# 	Fxx-(6-7,4)
# 	Fxx-(6,4-5)
# 	Fxx-(6,3-4)
# 	Fxx-(5-6,4)
# 	Fxy-(6, 4)
# Sending from X-(6, 4) to Fxx-(6-7,4)
# Sending from X-(6, 4) to Fxx-(6,4-5)
# Sending from X-(6, 4) to Fxx-(6,3-4)
# Sending from X-(6, 4) to Fxx-(5-6,4)
# Sending from X-(6, 4) to Fxy-(6, 4)
#
#
# Current node: X-(6, 5)
# Pending:
# 	Fxx-(6,5-6)
# 	Fxx-(6-7,5)
# 	Fxx-(6,4-5)
# 	Fxy-(6, 5)
# 	Fxx-(5-6,5)
# Sending from X-(6, 5) to Fxx-(6,5-6)
# Sending from X-(6, 5) to Fxx-(6-7,5)
# Sending from X-(6, 5) to Fxx-(6,4-5)
# Sending from X-(6, 5) to Fxy-(6, 5)
# Sending from X-(6, 5) to Fxx-(5-6,5)
#
#
# Current node: X-(6, 6)
# Pending:
# 	Fxx-(6,5-6)
# 	Fxy-(6, 6)
# 	Fxx-(6,6-7)
# 	Fxx-(5-6,6)
# 	Fxx-(6-7,6)
# Sending from X-(6, 6) to Fxx-(6,5-6)
# Sending from X-(6, 6) to Fxy-(6, 6)
# Sending from X-(6, 6) to Fxx-(6,6-7)
# Sending from X-(6, 6) to Fxx-(5-6,6)
# Sending from X-(6, 6) to Fxx-(6-7,6)
#
#
# Current node: X-(6, 7)
# Pending:
# 	Fxy-(6, 7)
# 	Fxx-(6,6-7)
# 	Fxx-(5-6,7)
# 	Fxx-(6,7-8)
# 	Fxx-(6-7,7)
# Sending from X-(6, 7) to Fxy-(6, 7)
# Sending from X-(6, 7) to Fxx-(6,6-7)
# Sending from X-(6, 7) to Fxx-(5-6,7)
# Sending from X-(6, 7) to Fxx-(6,7-8)
# Sending from X-(6, 7) to Fxx-(6-7,7)
#
#
# Current node: X-(6, 8)
# Pending:
# 	Fxx-(6,8-9)
# 	Fxy-(6, 8)
# 	Fxx-(5-6,8)
# 	Fxx-(6,7-8)
# 	Fxx-(6-7,8)
# Sending from X-(6, 8) to Fxx-(6,8-9)
# Sending from X-(6, 8) to Fxy-(6, 8)
# Sending from X-(6, 8) to Fxx-(5-6,8)
# Sending from X-(6, 8) to Fxx-(6,7-8)
# Sending from X-(6, 8) to Fxx-(6-7,8)
#
#
# Current node: X-(6, 9)
# Pending:
# 	Fxx-(5-6,9)
# 	Fxx-(6,8-9)
# 	Fxx-(6-7,9)
# 	Fxy-(6, 9)
# Sending from X-(6, 9) to Fxx-(5-6,9)
# Sending from X-(6, 9) to Fxx-(6,8-9)
# Sending from X-(6, 9) to Fxx-(6-7,9)
# Sending from X-(6, 9) to Fxy-(6, 9)
#
#
# Current node: X-(7, 0)
# Pending:
# 	Fxx-(7-8,0)
# 	Fxy-(7, 0)
# 	Fxx-(7,0-1)
# 	Fxx-(6-7,0)
# Sending from X-(7, 0) to Fxx-(7-8,0)
# Sending from X-(7, 0) to Fxy-(7, 0)
# Sending from X-(7, 0) to Fxx-(7,0-1)
# Sending from X-(7, 0) to Fxx-(6-7,0)
#
#
# Current node: X-(7, 1)
# Pending:
# 	Fxx-(7-8,1)
# 	Fxy-(7, 1)
# 	Fxx-(7,1-2)
# 	Fxx-(7,0-1)
# 	Fxx-(6-7,1)
# Sending from X-(7, 1) to Fxx-(7-8,1)
# Sending from X-(7, 1) to Fxy-(7, 1)
# Sending from X-(7, 1) to Fxx-(7,1-2)
# Sending from X-(7, 1) to Fxx-(7,0-1)
# Sending from X-(7, 1) to Fxx-(6-7,1)
#
#
# Current node: X-(7, 2)
# Pending:
# 	Fxx-(7-8,2)
# 	Fxx-(7,2-3)
# 	Fxy-(7, 2)
# 	Fxx-(7,1-2)
# 	Fxx-(6-7,2)
# Sending from X-(7, 2) to Fxx-(7-8,2)
# Sending from X-(7, 2) to Fxx-(7,2-3)
# Sending from X-(7, 2) to Fxy-(7, 2)
# Sending from X-(7, 2) to Fxx-(7,1-2)
# Sending from X-(7, 2) to Fxx-(6-7,2)
#
#
# Current node: X-(7, 3)
# Pending:
# 	Fxx-(7-8,3)
# 	Fxx-(7,2-3)
# 	Fxy-(7, 3)
# 	Fxx-(7,3-4)
# 	Fxx-(6-7,3)
# Sending from X-(7, 3) to Fxx-(7-8,3)
# Sending from X-(7, 3) to Fxx-(7,2-3)
# Sending from X-(7, 3) to Fxy-(7, 3)
# Sending from X-(7, 3) to Fxx-(7,3-4)
# Sending from X-(7, 3) to Fxx-(6-7,3)
#
#
# Current node: X-(7, 4)
# Pending:
# 	Fxx-(6-7,4)
# 	Fxx-(7-8,4)
# 	Fxx-(7,4-5)
# 	Fxy-(7, 4)
# 	Fxx-(7,3-4)
# Sending from X-(7, 4) to Fxx-(6-7,4)
# Sending from X-(7, 4) to Fxx-(7-8,4)
# Sending from X-(7, 4) to Fxx-(7,4-5)
# Sending from X-(7, 4) to Fxy-(7, 4)
# Sending from X-(7, 4) to Fxx-(7,3-4)
#
#
# Current node: X-(7, 5)
# Pending:
# 	Fxx-(6-7,5)
# 	Fxx-(7-8,5)
# 	Fxx-(7,4-5)
# 	Fxx-(7,5-6)
# 	Fxy-(7, 5)
# Sending from X-(7, 5) to Fxx-(6-7,5)
# Sending from X-(7, 5) to Fxx-(7-8,5)
# Sending from X-(7, 5) to Fxx-(7,4-5)
# Sending from X-(7, 5) to Fxx-(7,5-6)
# Sending from X-(7, 5) to Fxy-(7, 5)
#
#
# Current node: X-(7, 6)
# Pending:
# 	Fxx-(7,6-7)
# 	Fxx-(7-8,6)
# 	Fxx-(7,5-6)
# 	Fxy-(7, 6)
# 	Fxx-(6-7,6)
# Sending from X-(7, 6) to Fxx-(7,6-7)
# Sending from X-(7, 6) to Fxx-(7-8,6)
# Sending from X-(7, 6) to Fxx-(7,5-6)
# Sending from X-(7, 6) to Fxy-(7, 6)
# Sending from X-(7, 6) to Fxx-(6-7,6)
#
#
# Current node: X-(7, 7)
# Pending:
# 	Fxx-(7,6-7)
# 	Fxx-(7-8,7)
# 	Fxy-(7, 7)
# 	Fxx-(7,7-8)
# 	Fxx-(6-7,7)
# Sending from X-(7, 7) to Fxx-(7,6-7)
# Sending from X-(7, 7) to Fxx-(7-8,7)
# Sending from X-(7, 7) to Fxy-(7, 7)
# Sending from X-(7, 7) to Fxx-(7,7-8)
# Sending from X-(7, 7) to Fxx-(6-7,7)
#
#
# Current node: X-(7, 8)
# Pending:
# 	Fxx-(7-8,8)
# 	Fxx-(7,8-9)
# 	Fxy-(7, 8)
# 	Fxx-(7,7-8)
# 	Fxx-(6-7,8)
# Sending from X-(7, 8) to Fxx-(7-8,8)
# Sending from X-(7, 8) to Fxx-(7,8-9)
# Sending from X-(7, 8) to Fxy-(7, 8)
# Sending from X-(7, 8) to Fxx-(7,7-8)
# Sending from X-(7, 8) to Fxx-(6-7,8)
#
#
# Current node: X-(7, 9)
# Pending:
# 	Fxx-(7-8,9)
# 	Fxy-(7, 9)
# 	Fxx-(7,8-9)
# 	Fxx-(6-7,9)
# Sending from X-(7, 9) to Fxx-(7-8,9)
# Sending from X-(7, 9) to Fxy-(7, 9)
# Sending from X-(7, 9) to Fxx-(7,8-9)
# Sending from X-(7, 9) to Fxx-(6-7,9)
#
#
# Current node: X-(8, 0)
# Pending:
# 	Fxx-(8,0-1)
# 	Fxy-(8, 0)
# 	Fxx-(7-8,0)
# 	Fxx-(8-9,0)
# Sending from X-(8, 0) to Fxx-(8,0-1)
# Sending from X-(8, 0) to Fxy-(8, 0)
# Sending from X-(8, 0) to Fxx-(7-8,0)
# Sending from X-(8, 0) to Fxx-(8-9,0)
#
#
# Current node: X-(8, 1)
# Pending:
# 	Fxx-(7-8,1)
# 	Fxx-(8-9,1)
# 	Fxx-(8,0-1)
# 	Fxx-(8,1-2)
# 	Fxy-(8, 1)
# Sending from X-(8, 1) to Fxx-(7-8,1)
# Sending from X-(8, 1) to Fxx-(8-9,1)
# Sending from X-(8, 1) to Fxx-(8,0-1)
# Sending from X-(8, 1) to Fxx-(8,1-2)
# Sending from X-(8, 1) to Fxy-(8, 1)
#
#
# Current node: X-(8, 2)
# Pending:
# 	Fxx-(7-8,2)
# 	Fxx-(8-9,2)
# 	Fxy-(8, 2)
# 	Fxx-(8,1-2)
# 	Fxx-(8,2-3)
# Sending from X-(8, 2) to Fxx-(7-8,2)
# Sending from X-(8, 2) to Fxx-(8-9,2)
# Sending from X-(8, 2) to Fxy-(8, 2)
# Sending from X-(8, 2) to Fxx-(8,1-2)
# Sending from X-(8, 2) to Fxx-(8,2-3)
#
#
# Current node: X-(8, 3)
# Pending:
# 	Fxx-(7-8,3)
# 	Fxx-(8-9,3)
# 	Fxx-(8,2-3)
# 	Fxy-(8, 3)
# 	Fxx-(8,3-4)
# Sending from X-(8, 3) to Fxx-(7-8,3)
# Sending from X-(8, 3) to Fxx-(8-9,3)
# Sending from X-(8, 3) to Fxx-(8,2-3)
# Sending from X-(8, 3) to Fxy-(8, 3)
# Sending from X-(8, 3) to Fxx-(8,3-4)
#
#
# Current node: X-(8, 4)
# Pending:
# 	Fxx-(7-8,4)
# 	Fxx-(8-9,4)
# 	Fxx-(8,3-4)
# 	Fxx-(8,4-5)
# 	Fxy-(8, 4)
# Sending from X-(8, 4) to Fxx-(7-8,4)
# Sending from X-(8, 4) to Fxx-(8-9,4)
# Sending from X-(8, 4) to Fxx-(8,3-4)
# Sending from X-(8, 4) to Fxx-(8,4-5)
# Sending from X-(8, 4) to Fxy-(8, 4)
#
#
# Current node: X-(8, 5)
# Pending:
# 	Fxx-(7-8,5)
# 	Fxx-(8-9,5)
# 	Fxy-(8, 5)
# 	Fxx-(8,4-5)
# 	Fxx-(8,5-6)
# Sending from X-(8, 5) to Fxx-(7-8,5)
# Sending from X-(8, 5) to Fxx-(8-9,5)
# Sending from X-(8, 5) to Fxy-(8, 5)
# Sending from X-(8, 5) to Fxx-(8,4-5)
# Sending from X-(8, 5) to Fxx-(8,5-6)
#
#
# Current node: X-(8, 6)
# Pending:
# 	Fxx-(7-8,6)
# 	Fxx-(8-9,6)
# 	Fxy-(8, 6)
# 	Fxx-(8,5-6)
# 	Fxx-(8,6-7)
# Sending from X-(8, 6) to Fxx-(7-8,6)
# Sending from X-(8, 6) to Fxx-(8-9,6)
# Sending from X-(8, 6) to Fxy-(8, 6)
# Sending from X-(8, 6) to Fxx-(8,5-6)
# Sending from X-(8, 6) to Fxx-(8,6-7)
#
#
# Current node: X-(8, 7)
# Pending:
# 	Fxx-(7-8,7)
# 	Fxx-(8,7-8)
# 	Fxx-(8-9,7)
# 	Fxy-(8, 7)
# 	Fxx-(8,6-7)
# Sending from X-(8, 7) to Fxx-(7-8,7)
# Sending from X-(8, 7) to Fxx-(8,7-8)
# Sending from X-(8, 7) to Fxx-(8-9,7)
# Sending from X-(8, 7) to Fxy-(8, 7)
# Sending from X-(8, 7) to Fxx-(8,6-7)
#
#
# Current node: X-(8, 8)
# Pending:
# 	Fxx-(7-8,8)
# 	Fxx-(8,7-8)
# 	Fxx-(8-9,8)
# 	Fxx-(8,8-9)
# 	Fxy-(8, 8)
# Sending from X-(8, 8) to Fxx-(7-8,8)
# Sending from X-(8, 8) to Fxx-(8,7-8)
# Sending from X-(8, 8) to Fxx-(8-9,8)
# Sending from X-(8, 8) to Fxx-(8,8-9)
# Sending from X-(8, 8) to Fxy-(8, 8)
#
#
# Current node: X-(8, 9)
# Pending:
# 	Fxx-(7-8,9)
# 	Fxx-(8,8-9)
# 	Fxx-(8-9,9)
# 	Fxy-(8, 9)
# Sending from X-(8, 9) to Fxx-(7-8,9)
# Sending from X-(8, 9) to Fxx-(8,8-9)
# Sending from X-(8, 9) to Fxx-(8-9,9)
# Sending from X-(8, 9) to Fxy-(8, 9)
#
#
# Current node: X-(9, 0)
# Pending:
# 	Fxx-(9,0-1)
# 	Fxx-(8-9,0)
# 	Fxy-(9, 0)
# Sending from X-(9, 0) to Fxx-(9,0-1)
# Sending from X-(9, 0) to Fxx-(8-9,0)
# Sending from X-(9, 0) to Fxy-(9, 0)
#
#
# Current node: X-(9, 1)
# Pending:
# 	Fxx-(9,1-2)
# 	Fxx-(9,0-1)
# 	Fxy-(9, 1)
# 	Fxx-(8-9,1)
# Sending from X-(9, 1) to Fxx-(9,1-2)
# Sending from X-(9, 1) to Fxx-(9,0-1)
# Sending from X-(9, 1) to Fxy-(9, 1)
# Sending from X-(9, 1) to Fxx-(8-9,1)
#
#
# Current node: X-(9, 2)
# Pending:
# 	Fxx-(9,2-3)
# 	Fxx-(8-9,2)
# 	Fxx-(9,1-2)
# 	Fxy-(9, 2)
# Sending from X-(9, 2) to Fxx-(9,2-3)
# Sending from X-(9, 2) to Fxx-(8-9,2)
# Sending from X-(9, 2) to Fxx-(9,1-2)
# Sending from X-(9, 2) to Fxy-(9, 2)
#
#
# Current node: X-(9, 3)
# Pending:
# 	Fxx-(8-9,3)
# 	Fxx-(9,2-3)
# 	Fxy-(9, 3)
# 	Fxx-(9,3-4)
# Sending from X-(9, 3) to Fxx-(8-9,3)
# Sending from X-(9, 3) to Fxx-(9,2-3)
# Sending from X-(9, 3) to Fxy-(9, 3)
# Sending from X-(9, 3) to Fxx-(9,3-4)
#
#
# Current node: X-(9, 4)
# Pending:
# 	Fxx-(9,4-5)
# 	Fxx-(9,3-4)
# 	Fxx-(8-9,4)
# 	Fxy-(9, 4)
# Sending from X-(9, 4) to Fxx-(9,4-5)
# Sending from X-(9, 4) to Fxx-(9,3-4)
# Sending from X-(9, 4) to Fxx-(8-9,4)
# Sending from X-(9, 4) to Fxy-(9, 4)
#
#
# Current node: X-(9, 5)
# Pending:
# 	Fxx-(9,4-5)
# 	Fxy-(9, 5)
# 	Fxx-(9,5-6)
# 	Fxx-(8-9,5)
# Sending from X-(9, 5) to Fxx-(9,4-5)
# Sending from X-(9, 5) to Fxy-(9, 5)
# Sending from X-(9, 5) to Fxx-(9,5-6)
# Sending from X-(9, 5) to Fxx-(8-9,5)
#
#
# Current node: X-(9, 6)
# Pending:
# 	Fxx-(9,5-6)
# 	Fxy-(9, 6)
# 	Fxx-(8-9,6)
# 	Fxx-(9,6-7)
# Sending from X-(9, 6) to Fxx-(9,5-6)
# Sending from X-(9, 6) to Fxy-(9, 6)
# Sending from X-(9, 6) to Fxx-(8-9,6)
# Sending from X-(9, 6) to Fxx-(9,6-7)
#
#
# Current node: X-(9, 7)
# Pending:
# 	Fxx-(9,7-8)
# 	Fxy-(9, 7)
# 	Fxx-(8-9,7)
# 	Fxx-(9,6-7)
# Sending from X-(9, 7) to Fxx-(9,7-8)
# Sending from X-(9, 7) to Fxy-(9, 7)
# Sending from X-(9, 7) to Fxx-(8-9,7)
# Sending from X-(9, 7) to Fxx-(9,6-7)
#
#
# Current node: X-(9, 8)
# Pending:
# 	Fxx-(9,7-8)
# 	Fxy-(9, 8)
# 	Fxx-(9,8-9)
# 	Fxx-(8-9,8)
# Sending from X-(9, 8) to Fxx-(9,7-8)
# Sending from X-(9, 8) to Fxy-(9, 8)
# Sending from X-(9, 8) to Fxx-(9,8-9)
# Sending from X-(9, 8) to Fxx-(8-9,8)
#
#
# Current node: X-(9, 9)
# Pending:
# 	Fxx-(9,8-9)
# 	Fxx-(8-9,9)
# 	Fxy-(9, 9)
# Sending from X-(9, 9) to Fxx-(9,8-9)
# Sending from X-(9, 9) to Fxx-(8-9,9)
# Sending from X-(9, 9) to Fxy-(9, 9)
#
#
# Current node: Fxx-(0,0-1)
# Pending:
# 	X-(0, 1)
# 	X-(0, 0)
# Sending from Fxx-(0,0-1) to X-(0, 1)
# Sending from Fxx-(0,0-1) to X-(0, 0)
#
#
# Current node: Fxx-(0,1-2)
# Pending:
# 	X-(0, 1)
# 	X-(0, 2)
# Sending from Fxx-(0,1-2) to X-(0, 1)
# Sending from Fxx-(0,1-2) to X-(0, 2)
#
#
# Current node: Fxx-(0,2-3)
# Pending:
# 	X-(0, 3)
# 	X-(0, 2)
# Sending from Fxx-(0,2-3) to X-(0, 3)
# Sending from Fxx-(0,2-3) to X-(0, 2)
#
#
# Current node: Fxx-(0,3-4)
# Pending:
# 	X-(0, 3)
# 	X-(0, 4)
# Sending from Fxx-(0,3-4) to X-(0, 3)
# Sending from Fxx-(0,3-4) to X-(0, 4)
#
#
# Current node: Fxx-(0,4-5)
# Pending:
# 	X-(0, 4)
# 	X-(0, 5)
# Sending from Fxx-(0,4-5) to X-(0, 4)
# Sending from Fxx-(0,4-5) to X-(0, 5)
#
#
# Current node: Fxx-(0,5-6)
# Pending:
# 	X-(0, 5)
# 	X-(0, 6)
# Sending from Fxx-(0,5-6) to X-(0, 5)
# Sending from Fxx-(0,5-6) to X-(0, 6)
#
#
# ...
# Sending from X-(1, 7) to Fxx-(0-1,7)
# Sending from X-(1, 7) to Fxx-(1,6-7)
# Sending from X-(1, 7) to Fxx-(1-2,7)
# Sending from X-(1, 7) to Fxy-(1, 7)
#
#
# Current node: X-(1, 6)
# Pending:
# 	Fxx-(1,6-7)
# 	Fxx-(0-1,6)
# 	Fxx-(1-2,6)
# 	Fxy-(1, 6)
# 	Fxx-(1,5-6)
# Sending from X-(1, 6) to Fxx-(1,6-7)
# Sending from X-(1, 6) to Fxx-(0-1,6)
# Sending from X-(1, 6) to Fxx-(1-2,6)
# Sending from X-(1, 6) to Fxy-(1, 6)
# Sending from X-(1, 6) to Fxx-(1,5-6)
#
#
# Current node: X-(1, 5)
# Pending:
# 	Fxx-(0-1,5)
# 	Fxx-(1-2,5)
# 	Fxy-(1, 5)
# 	Fxx-(1,4-5)
# 	Fxx-(1,5-6)
# Sending from X-(1, 5) to Fxx-(0-1,5)
# Sending from X-(1, 5) to Fxx-(1-2,5)
# Sending from X-(1, 5) to Fxy-(1, 5)
# Sending from X-(1, 5) to Fxx-(1,4-5)
# Sending from X-(1, 5) to Fxx-(1,5-6)
#
#
# Current node: X-(1, 4)
# Pending:
# 	Fxx-(0-1,4)
# 	Fxx-(1-2,4)
# 	Fxx-(1,3-4)
# 	Fxx-(1,4-5)
# 	Fxy-(1, 4)
# Sending from X-(1, 4) to Fxx-(0-1,4)
# Sending from X-(1, 4) to Fxx-(1-2,4)
# Sending from X-(1, 4) to Fxx-(1,3-4)
# Sending from X-(1, 4) to Fxx-(1,4-5)
# Sending from X-(1, 4) to Fxy-(1, 4)
#
#
# Current node: X-(1, 3)
# Pending:
# 	Fxx-(1,2-3)
# 	Fxy-(1, 3)
# 	Fxx-(0-1,3)
# 	Fxx-(1-2,3)
# 	Fxx-(1,3-4)
# Sending from X-(1, 3) to Fxx-(1,2-3)
# Sending from X-(1, 3) to Fxy-(1, 3)
# Sending from X-(1, 3) to Fxx-(0-1,3)
# Sending from X-(1, 3) to Fxx-(1-2,3)
# Sending from X-(1, 3) to Fxx-(1,3-4)
#
#
# Current node: X-(1, 2)
# Pending:
# 	Fxx-(1,2-3)
# 	Fxy-(1, 2)
# 	Fxx-(0-1,2)
# 	Fxx-(1-2,2)
# 	Fxx-(1,1-2)
# Sending from X-(1, 2) to Fxx-(1,2-3)
# Sending from X-(1, 2) to Fxy-(1, 2)
# Sending from X-(1, 2) to Fxx-(0-1,2)
# Sending from X-(1, 2) to Fxx-(1-2,2)
# Sending from X-(1, 2) to Fxx-(1,1-2)
#
#
# Current node: X-(1, 1)
# Pending:
# 	Fxy-(1, 1)
# 	Fxx-(0-1,1)
# 	Fxx-(1-2,1)
# 	Fxx-(1,0-1)
# 	Fxx-(1,1-2)
# Sending from X-(1, 1) to Fxy-(1, 1)
# Sending from X-(1, 1) to Fxx-(0-1,1)
# Sending from X-(1, 1) to Fxx-(1-2,1)
# Sending from X-(1, 1) to Fxx-(1,0-1)
# Sending from X-(1, 1) to Fxx-(1,1-2)
#
#
# Current node: X-(1, 0)
# Pending:
# 	Fxx-(0-1,0)
# 	Fxx-(1-2,0)
# 	Fxx-(1,0-1)
# 	Fxy-(1, 0)
# Sending from X-(1, 0) to Fxx-(0-1,0)
# Sending from X-(1, 0) to Fxx-(1-2,0)
# Sending from X-(1, 0) to Fxx-(1,0-1)
# Sending from X-(1, 0) to Fxy-(1, 0)
#
#
# Current node: X-(0, 9)
# Pending:
# 	Fxx-(0-1,9)
# 	Fxx-(0,8-9)
# 	Fxy-(0, 9)
# Sending from X-(0, 9) to Fxx-(0-1,9)
# Sending from X-(0, 9) to Fxx-(0,8-9)
# Sending from X-(0, 9) to Fxy-(0, 9)
#
#
# Current node: X-(0, 8)
# Pending:
# 	Fxx-(0-1,8)
# 	Fxx-(0,8-9)
# 	Fxy-(0, 8)
# 	Fxx-(0,7-8)
# Sending from X-(0, 8) to Fxx-(0-1,8)
# Sending from X-(0, 8) to Fxx-(0,8-9)
# Sending from X-(0, 8) to Fxy-(0, 8)
# Sending from X-(0, 8) to Fxx-(0,7-8)
#
#
# Current node: X-(0, 7)
# Pending:
# 	Fxx-(0-1,7)
# 	Fxx-(0,6-7)
# 	Fxx-(0,7-8)
# 	Fxy-(0, 7)
# Sending from X-(0, 7) to Fxx-(0-1,7)
# Sending from X-(0, 7) to Fxx-(0,6-7)
# Sending from X-(0, 7) to Fxx-(0,7-8)
# Sending from X-(0, 7) to Fxy-(0, 7)
#
#
# Current node: X-(0, 6)
# Pending:
# 	Fxx-(0-1,6)
# 	Fxy-(0, 6)
# 	Fxx-(0,6-7)
# 	Fxx-(0,5-6)
# Sending from X-(0, 6) to Fxx-(0-1,6)
# Sending from X-(0, 6) to Fxy-(0, 6)
# Sending from X-(0, 6) to Fxx-(0,6-7)
# Sending from X-(0, 6) to Fxx-(0,5-6)
#
#
# Current node: X-(0, 5)
# Pending:
# 	Fxy-(0, 5)
# 	Fxx-(0-1,5)
# 	Fxx-(0,5-6)
# 	Fxx-(0,4-5)
# Sending from X-(0, 5) to Fxy-(0, 5)
# Sending from X-(0, 5) to Fxx-(0-1,5)
# Sending from X-(0, 5) to Fxx-(0,5-6)
# Sending from X-(0, 5) to Fxx-(0,4-5)
#
#
# Current node: X-(0, 4)
# Pending:
# 	Fxx-(0,3-4)
# 	Fxx-(0-1,4)
# 	Fxy-(0, 4)
# 	Fxx-(0,4-5)
# Sending from X-(0, 4) to Fxx-(0,3-4)
# Sending from X-(0, 4) to Fxx-(0-1,4)
# Sending from X-(0, 4) to Fxy-(0, 4)
# Sending from X-(0, 4) to Fxx-(0,4-5)
#
#
# Current node: X-(0, 3)
# Pending:
# 	Fxy-(0, 3)
# 	Fxx-(0,2-3)
# 	Fxx-(0,3-4)
# 	Fxx-(0-1,3)
# Sending from X-(0, 3) to Fxy-(0, 3)
# Sending from X-(0, 3) to Fxx-(0,2-3)
# Sending from X-(0, 3) to Fxx-(0,3-4)
# Sending from X-(0, 3) to Fxx-(0-1,3)
#
#
# Current node: X-(0, 2)
# Pending:
# 	Fxx-(0-1,2)
# 	Fxy-(0, 2)
# 	Fxx-(0,2-3)
# 	Fxx-(0,1-2)
# Sending from X-(0, 2) to Fxx-(0-1,2)
# Sending from X-(0, 2) to Fxy-(0, 2)
# Sending from X-(0, 2) to Fxx-(0,2-3)
# Sending from X-(0, 2) to Fxx-(0,1-2)
#
#
# Current node: X-(0, 1)
# Pending:
# 	Fxx-(0-1,1)
# 	Fxy-(0, 1)
# 	Fxx-(0,0-1)
# 	Fxx-(0,1-2)
# Sending from X-(0, 1) to Fxx-(0-1,1)
# Sending from X-(0, 1) to Fxy-(0, 1)
# Sending from X-(0, 1) to Fxx-(0,0-1)
# Sending from X-(0, 1) to Fxx-(0,1-2)
#
#
# Current node: X-(0, 0)
# Pending:
# 	Fxx-(0-1,0)
# 	Fxy-(0, 0)
# 	Fxx-(0,0-1)
# Sending from X-(0, 0) to Fxx-(0-1,0)
# Sending from X-(0, 0) to Fxy-(0, 0)
# Sending from X-(0, 0) to Fxx-(0,0-1)
#
#
# Current node: Fxy-(9, 9)
# Pending:
# 	Y-(9, 9)
# Sending from Fxy-(9, 9) to Y-(9, 9)
#
#
# Current node: Fxy-(9, 8)
# Pending:
# 	Y-(9, 8)
# Sending from Fxy-(9, 8) to Y-(9, 8)
#
#
# Current node: Fxy-(9, 7)
# Pending:
# 	Y-(9, 7)
# Sending from Fxy-(9, 7) to Y-(9, 7)
#
#
# Current node: Fxy-(9, 6)
# Pending:
# 	Y-(9, 6)
# Sending from Fxy-(9, 6) to Y-(9, 6)
#
#
# Current node: Fxy-(9, 5)
# Pending:
# 	Y-(9, 5)
# Sending from Fxy-(9, 5) to Y-(9, 5)
#
#
# Current node: Fxy-(9, 4)
# Pending:
# 	Y-(9, 4)
# Sending from Fxy-(9, 4) to Y-(9, 4)
#
#
# Current node: Fxy-(9, 3)
# Pending:
# 	Y-(9, 3)
# Sending from Fxy-(9, 3) to Y-(9, 3)
#
#
# Current node: Fxy-(9, 2)
# Pending:
# 	Y-(9, 2)
# Sending from Fxy-(9, 2) to Y-(9, 2)
#
#
# Current node: Fxy-(9, 1)
# Pending:
# 	Y-(9, 1)
# Sending from Fxy-(9, 1) to Y-(9, 1)
#
#
# Current node: Fxy-(9, 0)
# Pending:
# 	Y-(9, 0)
# Sending from Fxy-(9, 0) to Y-(9, 0)
#
#
# Current node: Fxy-(8, 9)
# Pending:
# 	Y-(8, 9)
# Sending from Fxy-(8, 9) to Y-(8, 9)
#
#
# Current node: Fxy-(8, 8)
# Pending:
# 	Y-(8, 8)
# Sending from Fxy-(8, 8) to Y-(8, 8)
#
#
# Current node: Fxy-(8, 7)
# Pending:
# 	Y-(8, 7)
# Sending from Fxy-(8, 7) to Y-(8, 7)
#
#
# Current node: Fxy-(8, 6)
# Pending:
# 	Y-(8, 6)
# Sending from Fxy-(8, 6) to Y-(8, 6)
#
#
# Current node: Fxy-(8, 5)
# Pending:
# 	Y-(8, 5)
# Sending from Fxy-(8, 5) to Y-(8, 5)
#
#
# Current node: Fxy-(8, 4)
# Pending:
# 	Y-(8, 4)
# Sending from Fxy-(8, 4) to Y-(8, 4)
#
#
# Current node: Fxy-(8, 3)
# Pending:
# 	Y-(8, 3)
# Sending from Fxy-(8, 3) to Y-(8, 3)
#
#
# Current node: Fxy-(8, 2)
# Pending:
# 	Y-(8, 2)
# Sending from Fxy-(8, 2) to Y-(8, 2)
#
#
# Current node: Fxy-(8, 1)
# Pending:
# 	Y-(8, 1)
# Sending from Fxy-(8, 1) to Y-(8, 1)
#
#
# Current node: Fxy-(8, 0)
# Pending:
# 	Y-(8, 0)
# Sending from Fxy-(8, 0) to Y-(8, 0)
#
#
# Current node: Fxy-(7, 9)
# Pending:
# 	Y-(7, 9)
# Sending from Fxy-(7, 9) to Y-(7, 9)
#
#
# Current node: Fxy-(7, 8)
# Pending:
# 	Y-(7, 8)
# Sending from Fxy-(7, 8) to Y-(7, 8)
#
#
# Current node: Fxy-(7, 7)
# Pending:
# 	Y-(7, 7)
# Sending from Fxy-(7, 7) to Y-(7, 7)
#
#
# Current node: Fxy-(7, 6)
# Pending:
# 	Y-(7, 6)
# Sending from Fxy-(7, 6) to Y-(7, 6)
#
#
# Current node: Fxy-(7, 5)
# Pending:
# 	Y-(7, 5)
# Sending from Fxy-(7, 5) to Y-(7, 5)
#
#
# Current node: Fxy-(7, 4)
# Pending:
# 	Y-(7, 4)
# Sending from Fxy-(7, 4) to Y-(7, 4)
#
#
# Current node: Fxy-(7, 3)
# Pending:
# 	Y-(7, 3)
# Sending from Fxy-(7, 3) to Y-(7, 3)
#
#
# Current node: Fxy-(7, 2)
# Pending:
# 	Y-(7, 2)
# Sending from Fxy-(7, 2) to Y-(7, 2)
#
#
# Current node: Fxy-(7, 1)
# Pending:
# 	Y-(7, 1)
# Sending from Fxy-(7, 1) to Y-(7, 1)
#
#
# Current node: Fxy-(7, 0)
# Pending:
# 	Y-(7, 0)
# Sending from Fxy-(7, 0) to Y-(7, 0)
#
#
# Current node: Fxy-(6, 9)
# Pending:
# 	Y-(6, 9)
# Sending from Fxy-(6, 9) to Y-(6, 9)
#
#
# Current node: Fxy-(6, 8)
# Pending:
# 	Y-(6, 8)
# Sending from Fxy-(6, 8) to Y-(6, 8)
#
#
# Current node: Fxy-(6, 7)
# Pending:
# 	Y-(6, 7)
# Sending from Fxy-(6, 7) to Y-(6, 7)
#
#
# Current node: Fxy-(6, 6)
# Pending:
# 	Y-(6, 6)
# Sending from Fxy-(6, 6) to Y-(6, 6)
#
#
# Current node: Fxy-(6, 5)
# Pending:
# 	Y-(6, 5)
# Sending from Fxy-(6, 5) to Y-(6, 5)
#
#
# Current node: Fxy-(6, 4)
# Pending:
# 	Y-(6, 4)
# Sending from Fxy-(6, 4) to Y-(6, 4)
#
#
# Current node: Fxy-(6, 3)
# Pending:
# 	Y-(6, 3)
# Sending from Fxy-(6, 3) to Y-(6, 3)
#
#
# Current node: Fxy-(6, 2)
# Pending:
# 	Y-(6, 2)
# Sending from Fxy-(6, 2) to Y-(6, 2)
#
#
# Current node: Fxy-(6, 1)
# Pending:
# 	Y-(6, 1)
# Sending from Fxy-(6, 1) to Y-(6, 1)
#
#
# Current node: Fxy-(6, 0)
# Pending:
# 	Y-(6, 0)
# Sending from Fxy-(6, 0) to Y-(6, 0)
#
#
# Current node: Fxy-(5, 9)
# Pending:
# 	Y-(5, 9)
# Sending from Fxy-(5, 9) to Y-(5, 9)
#
#
# Current node: Fxy-(5, 8)
# Pending:
# 	Y-(5, 8)
# Sending from Fxy-(5, 8) to Y-(5, 8)
#
#
# Current node: Fxy-(5, 7)
# Pending:
# 	Y-(5, 7)
# Sending from Fxy-(5, 7) to Y-(5, 7)
#
#
# Current node: Fxy-(5, 6)
# Pending:
# 	Y-(5, 6)
# Sending from Fxy-(5, 6) to Y-(5, 6)
#
#
# Current node: Fxy-(5, 5)
# Pending:
# 	Y-(5, 5)
# Sending from Fxy-(5, 5) to Y-(5, 5)
#
#
# Current node: Fxy-(5, 4)
# Pending:
# 	Y-(5, 4)
# Sending from Fxy-(5, 4) to Y-(5, 4)
#
#
# Current node: Fxy-(5, 3)
# Pending:
# 	Y-(5, 3)
# Sending from Fxy-(5, 3) to Y-(5, 3)
#
#
# Current node: Fxy-(5, 2)
# Pending:
# 	Y-(5, 2)
# Sending from Fxy-(5, 2) to Y-(5, 2)
#
#
# Current node: Fxy-(5, 1)
# Pending:
# 	Y-(5, 1)
# Sending from Fxy-(5, 1) to Y-(5, 1)
#
#
# Current node: Fxy-(5, 0)
# Pending:
# 	Y-(5, 0)
# Sending from Fxy-(5, 0) to Y-(5, 0)
#
#
# Current node: Fxy-(4, 9)
# Pending:
# 	Y-(4, 9)
# Sending from Fxy-(4, 9) to Y-(4, 9)
#
#
# Current node: Fxy-(4, 8)
# Pending:
# 	Y-(4, 8)
# Sending from Fxy-(4, 8) to Y-(4, 8)
#
#
# Current node: Fxy-(4, 7)
# Pending:
# 	Y-(4, 7)
# Sending from Fxy-(4, 7) to Y-(4, 7)
#
#
# Current node: Fxy-(4, 6)
# Pending:
# 	Y-(4, 6)
# Sending from Fxy-(4, 6) to Y-(4, 6)
#
#
# Current node: Fxy-(4, 5)
# Pending:
# 	Y-(4, 5)
# Sending from Fxy-(4, 5) to Y-(4, 5)
#
#
# Current node: Fxy-(4, 4)
# Pending:
# 	Y-(4, 4)
# Sending from Fxy-(4, 4) to Y-(4, 4)
#
#
# Current node: Fxy-(4, 3)
# Pending:
# 	Y-(4, 3)
# Sending from Fxy-(4, 3) to Y-(4, 3)
#
#
# Current node: Fxy-(4, 2)
# Pending:
# 	Y-(4, 2)
# Sending from Fxy-(4, 2) to Y-(4, 2)
#
#
# Current node: Fxy-(4, 1)
# Pending:
# 	Y-(4, 1)
# Sending from Fxy-(4, 1) to Y-(4, 1)
#
#
# Current node: Fxy-(4, 0)
# Pending:
# 	Y-(4, 0)
# Sending from Fxy-(4, 0) to Y-(4, 0)
#
#
# Current node: Fxy-(3, 9)
# Pending:
# 	Y-(3, 9)
# Sending from Fxy-(3, 9) to Y-(3, 9)
#
#
# Current node: Fxy-(3, 8)
# Pending:
# 	Y-(3, 8)
# Sending from Fxy-(3, 8) to Y-(3, 8)
#
#
# Current node: Fxy-(3, 7)
# Pending:
# 	Y-(3, 7)
# Sending from Fxy-(3, 7) to Y-(3, 7)
#
#
# Current node: Fxy-(3, 6)
# Pending:
# 	Y-(3, 6)
# Sending from Fxy-(3, 6) to Y-(3, 6)
#
#
# Current node: Fxy-(3, 5)
# Pending:
# 	Y-(3, 5)
# Sending from Fxy-(3, 5) to Y-(3, 5)
#
#
# Current node: Fxy-(3, 4)
# Pending:
# 	Y-(3, 4)
# Sending from Fxy-(3, 4) to Y-(3, 4)
#
#
# Current node: Fxy-(3, 3)
# Pending:
# 	Y-(3, 3)
# Sending from Fxy-(3, 3) to Y-(3, 3)
#
#
# Current node: Fxy-(3, 2)
# Pending:
# 	Y-(3, 2)
# Sending from Fxy-(3, 2) to Y-(3, 2)
#
#
# Current node: Fxy-(3, 1)
# Pending:
# 	Y-(3, 1)
# Sending from Fxy-(3, 1) to Y-(3, 1)
#
#
# Current node: Fxy-(3, 0)
# Pending:
# 	Y-(3, 0)
# Sending from Fxy-(3, 0) to Y-(3, 0)
#
#
# Current node: Fxy-(2, 9)
# Pending:
# 	Y-(2, 9)
# Sending from Fxy-(2, 9) to Y-(2, 9)
#
#
# Current node: Fxy-(2, 8)
# Pending:
# 	Y-(2, 8)
# Sending from Fxy-(2, 8) to Y-(2, 8)
#
#
# Current node: Fxy-(2, 7)
# Pending:
# 	Y-(2, 7)
# Sending from Fxy-(2, 7) to Y-(2, 7)
#
#
# Current node: Fxy-(2, 6)
# Pending:
# 	Y-(2, 6)
# Sending from Fxy-(2, 6) to Y-(2, 6)
#
#
# Current node: Fxy-(2, 5)
# Pending:
# 	Y-(2, 5)
# Sending from Fxy-(2, 5) to Y-(2, 5)
#
#
# Current node: Fxy-(2, 4)
# Pending:
# 	Y-(2, 4)
# Sending from Fxy-(2, 4) to Y-(2, 4)
#
#
# Current node: Fxy-(2, 3)
# Pending:
# 	Y-(2, 3)
# Sending from Fxy-(2, 3) to Y-(2, 3)
#
#
# Current node: Fxy-(2, 2)
# Pending:
# 	Y-(2, 2)
# Sending from Fxy-(2, 2) to Y-(2, 2)
#
#
# Current node: Fxy-(2, 1)
# Pending:
# 	Y-(2, 1)
# Sending from Fxy-(2, 1) to Y-(2, 1)
#
#
# Current node: Fxy-(2, 0)
# Pending:
# 	Y-(2, 0)
# Sending from Fxy-(2, 0) to Y-(2, 0)
#
#
# Current node: Fxy-(1, 9)
# Pending:
# 	Y-(1, 9)
# Sending from Fxy-(1, 9) to Y-(1, 9)
#
#
# Current node: Fxy-(1, 8)
# Pending:
# 	Y-(1, 8)
# Sending from Fxy-(1, 8) to Y-(1, 8)
#
#
# Current node: Fxy-(1, 7)
# Pending:
# 	Y-(1, 7)
# Sending from Fxy-(1, 7) to Y-(1, 7)
#
#
# Current node: Fxy-(1, 6)
# Pending:
# 	Y-(1, 6)
# Sending from Fxy-(1, 6) to Y-(1, 6)
#
#
# Current node: Fxy-(1, 5)
# Pending:
# 	Y-(1, 5)
# Sending from Fxy-(1, 5) to Y-(1, 5)
#
#
# Current node: Fxy-(1, 4)
# Pending:
# 	Y-(1, 4)
# Sending from Fxy-(1, 4) to Y-(1, 4)
#
#
# Current node: Fxy-(1, 3)
# Pending:
# 	Y-(1, 3)
# Sending from Fxy-(1, 3) to Y-(1, 3)
#
#
# Current node: Fxy-(1, 2)
# Pending:
# 	Y-(1, 2)
# Sending from Fxy-(1, 2) to Y-(1, 2)
#
#
# Current node: Fxy-(1, 1)
# Pending:
# 	Y-(1, 1)
# Sending from Fxy-(1, 1) to Y-(1, 1)
#
#
# Current node: Fxy-(1, 0)
# Pending:
# 	Y-(1, 0)
# Sending from Fxy-(1, 0) to Y-(1, 0)
#
#
# Current node: Fxy-(0, 9)
# Pending:
# 	Y-(0, 9)
# Sending from Fxy-(0, 9) to Y-(0, 9)
#
#
# Current node: Fxy-(0, 8)
# Pending:
# 	Y-(0, 8)
# Sending from Fxy-(0, 8) to Y-(0, 8)
#
#
# Current node: Fxy-(0, 7)
# Pending:
# 	Y-(0, 7)
# Sending from Fxy-(0, 7) to Y-(0, 7)
#
#
# Current node: Fxy-(0, 6)
# Pending:
# 	Y-(0, 6)
# Sending from Fxy-(0, 6) to Y-(0, 6)
#
#
# Current node: Fxy-(0, 5)
# Pending:
# 	Y-(0, 5)
# Sending from Fxy-(0, 5) to Y-(0, 5)
#
#
# Current node: Fxy-(0, 4)
# Pending:
# 	Y-(0, 4)
# Sending from Fxy-(0, 4) to Y-(0, 4)
#
#
# Current node: Fxy-(0, 3)
# Pending:
# 	Y-(0, 3)
# Sending from Fxy-(0, 3) to Y-(0, 3)
#
#
# Current node: Fxy-(0, 2)
# Pending:
# 	Y-(0, 2)
# Sending from Fxy-(0, 2) to Y-(0, 2)
#
#
# Current node: Fxy-(0, 1)
# Pending:
# 	Y-(0, 1)
# Sending from Fxy-(0, 1) to Y-(0, 1)
#
#
# Current node: Fxy-(0, 0)
# Pending:
# 	Y-(0, 0)
# Sending from Fxy-(0, 0) to Y-(0, 0)
#
#
# Current node: Y-(9, 9)
# Pending:
#
#
#
# Current node: Y-(9, 8)
# Pending:
#
#
#
# Current node: Y-(9, 7)
# Pending:
#
#
#
# Current node: Y-(9, 6)
# Pending:
#
#
#
# Current node: Y-(9, 5)
# Pending:
#
#
#
# Current node: Y-(9, 4)
# Pending:
#
#
#
# Current node: Y-(9, 3)
# Pending:
#
#
#
# Current node: Y-(9, 2)
# Pending:
#
#
#
# Current node: Y-(9, 1)
# Pending:
#
#
#
# Current node: Y-(9, 0)
# Pending:
#
#
#
# Current node: Y-(8, 9)
# Pending:
#
#
#
# Current node: Y-(8, 8)
# Pending:
#
#
#
# Current node: Y-(8, 7)
# Pending:
#
#
#
# Current node: Y-(8, 6)
# Pending:
#
#
#
# Current node: Y-(8, 5)
# Pending:
#
#
#
# Current node: Y-(8, 4)
# Pending:
#
#
#
# Current node: Y-(8, 3)
# Pending:
#
#
#
# Current node: Y-(8, 2)
# Pending:
#
#
#
# Current node: Y-(8, 1)
# Pending:
#
#
#
# Current node: Y-(8, 0)
# Pending:
#
#
#
# Current node: Y-(7, 9)
# Pending:
#
#
#
# Current node: Y-(7, 8)
# Pending:
#
#
#
# Current node: Y-(7, 7)
# Pending:
#
#
#
# Current node: Y-(7, 6)
# Pending:
#
#
#
# Current node: Y-(7, 5)
# Pending:
#
#
#
# Current node: Y-(7, 4)
# Pending:
#
#
#
# Current node: Y-(7, 3)
# Pending:
#
#
#
# Current node: Y-(7, 2)
# Pending:
#
#
#
# Current node: Y-(7, 1)
# Pending:
#
#
#
# Current node: Y-(7, 0)
# Pending:
#
#
#
# Current node: Y-(6, 9)
# Pending:
#
#
#
# Current node: Y-(6, 8)
# Pending:
#
#
#
# Current node: Y-(6, 7)
# Pending:
#
#
#
# Current node: Y-(6, 6)
# Pending:
#
#
#
# Current node: Y-(6, 5)
# Pending:
#
#
#
# Current node: Y-(6, 4)
# Pending:
#
#
#
# Current node: Y-(6, 3)
# Pending:
#
#
#
# Current node: Y-(6, 2)
# Pending:
#
#
#
# Current node: Y-(6, 1)
# Pending:
#
#
#
# Current node: Y-(6, 0)
# Pending:
#
#
#
# Current node: Y-(5, 9)
# Pending:
#
#
#
# Current node: Y-(5, 8)
# Pending:
#
#
#
# Current node: Y-(5, 7)
# Pending:
#
#
#
# Current node: Y-(5, 6)
# Pending:
#
#
#
# Current node: Y-(5, 5)
# Pending:
#
#
#
# Current node: Y-(5, 4)
# Pending:
#
#
#
# Current node: Y-(5, 3)
# Pending:
#
#
#
# Current node: Y-(5, 2)
# Pending:
#
#
#
# Current node: Y-(5, 1)
# Pending:
#
#
#
# Current node: Y-(5, 0)
# Pending:
#
#
#
# Current node: Y-(4, 9)
# Pending:
#
#
#
# Current node: Y-(4, 8)
# Pending:
#
#
#
# Current node: Y-(4, 7)
# Pending:
#
#
#
# Current node: Y-(4, 6)
# Pending:
#
#
#
# Current node: Y-(4, 5)
# Pending:
#
#
#
# Current node: Y-(4, 4)
# Pending:
#
#
#
# Current node: Y-(4, 3)
# Pending:
#
#
#
# Current node: Y-(4, 2)
# Pending:
#
#
#
# Current node: Y-(4, 1)
# Pending:
#
#
#
# Current node: Y-(4, 0)
# Pending:
#
#
#
# Current node: Y-(3, 9)
# Pending:
#
#
#
# Current node: Y-(3, 8)
# Pending:
#
#
#
# Current node: Y-(3, 7)
# Pending:
#
#
#
# Current node: Y-(3, 6)
# Pending:
#
#
#
# Current node: Y-(3, 5)
# Pending:
#
#
#
# Current node: Y-(3, 4)
# Pending:
#
#
#
# Current node: Y-(3, 3)
# Pending:
#
#
#
# Current node: Y-(3, 2)
# Pending:
#
#
#
# Current node: Y-(3, 1)
# Pending:
#
#
#
# Current node: Y-(3, 0)
# Pending:
#
#
#
# Current node: Y-(2, 9)
# Pending:
#
#
#
# Current node: Y-(2, 8)
# Pending:
#
#
#
# Current node: Y-(2, 7)
# Pending:
#
#
#
# Current node: Y-(2, 6)
# Pending:
#
#
#
# Current node: Y-(2, 5)
# Pending:
#
#
#
# Current node: Y-(2, 4)
# Pending:
#
#
#
# Current node: Y-(2, 3)
# Pending:
#
#
#
# Current node: Y-(2, 2)
# Pending:
#
#
#
# Current node: Y-(2, 1)
# Pending:
#
#
#
# Current node: Y-(2, 0)
# Pending:
#
#
#
# Current node: Y-(1, 9)
# Pending:
#
#
#
# Current node: Y-(1, 8)
# Pending:
#
#
#
# Current node: Y-(1, 7)
# Pending:
#
#
#
# Current node: Y-(1, 6)
# Pending:
#
#
#
# Current node: Y-(1, 5)
# Pending:
#
#
#
# Current node: Y-(1, 4)
# Pending:
#
#
#
# Current node: Y-(1, 3)
# Pending:
#
#
#
# Current node: Y-(1, 2)
# Pending:
#
#
#
# Current node: Y-(1, 1)
# Pending:
#
#
#
# Current node: Y-(1, 0)
# Pending:
#
#
#
# Current node: Y-(0, 9)
# Pending:
#
#
#
# Current node: Y-(0, 8)
# Pending:
#
#
#
# Current node: Y-(0, 7)
# Pending:
#
#
#
# Current node: Y-(0, 6)
# Pending:
#
#
#
# Current node: Y-(0, 5)
# Pending:
#
#
#
# Current node: Y-(0, 4)
# Pending:
#
#
#
# Current node: Y-(0, 3)
# Pending:
#
#
#
# Current node: Y-(0, 2)
# Pending:
#
#
#
# Current node: Y-(0, 1)
# Pending:
#
#
#
# Current node: Y-(0, 0)
# Pending:

# %%
figure()
imshow(test_im)

figure()
imshow(noise_test_im)

figure()
imshow(denoised)

# %%
mrf = MRF(noise_im)
mrf.make_graph(flipping=0.1, similar=0.8)
mrf.max_sum(iterations=1)

denoised = mrf.denoised()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-798-f7538a9e9d27> in <module>()
#       1 mrf = MRF(noise_im)
# ----> 2 mrf.make_graph(flipping=0.1, similar=0.8)
#       3 mrf.max_sum(iterations=1)
#       4
#       5 denoised = mrf.denoised()
#
# <ipython-input-750-ee537442d2f7> in make_graph(self, flipping, similar)
#      21                 self.y_variables[i,j] = y
#      22                 # make x
# ---> 23                 x = Variable('X-{}'.format((i,j)), 2)
#      24                 self.x_variables[i,j] = x
#      25                 # make correlation-factor x-y
#
# <ipython-input-777-d557152cf5b3> in __init__(self, name, num_states)
#      86
#      87         # Call the base-class constructor
# ---> 88         super(Variable, self).__init__(name)
#      89
#      90     def set_observed(self, observed_state):
#
# <ipython-input-777-d557152cf5b3> in __init__(self, name)
#      13
#      14         # Reset the node-state (not the graph topology)
# ---> 15         self.reset()
#      16
#      17     def reset(self):
#
# <ipython-input-777-d557152cf5b3> in reset(self)
#     110     def reset(self):
#     111         super(Variable, self).reset()
# --> 112         self.observed_state = np.ones(self.num_states)
#     113
#     114     def marginal(self, Z=None):
#
# /Users/daan/anaconda/lib/python3.6/site-packages/numpy/core/numeric.py in ones(shape, dtype, order)
#     189     """
#     190     a = empty(shape, dtype, order)
# --> 191     multiarray.copyto(a, 1, casting='unsafe')
#     192     return a
#     193
#
# KeyboardInterrupt:

# %%
imshow(im)
gray()

figure()
imshow(noise_im)

figure()
imshow(denoised)

# %% [markdown]
# ### 3.2 Loopy max-sum (10 points)
# Implement the loopy max-sum algorithm, by passing messages from randomly chosen nodes iteratively until no more pending messages are created or a maximum number of iterations is reached.
#
# Think of a good way to initialize the messages in the graph.

# %%
# YOUR ANSWER hErE
